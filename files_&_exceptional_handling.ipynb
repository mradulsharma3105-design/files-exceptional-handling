# %% [markdown]
# # THEORETICAL QUESTIONS

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
# - > Compiled Languages:
#
# •	Source code is translated into machine code before execution.
#
# •	Examples: C, C++, Rust, Go.
#
# •	Faster execution since code is pre-compiled.
#
# •	Platform-specific executables.
#
# •	Errors caught at compile time.
#
# Interpreted Languages:
#
# •	Source code is executed line by line at runtime.
#
# •	Examples: Python, JavaScript, Ruby.
#
# •	Slower execution due to runtime interpretation.
#
# •	Platform independent (with interpreter installed).
#
# •	Errors caught at runtime.

# %% [markdown]
# 2. What is exception handling in Python?
# - > Exception handling is a programming construct that allows you to catch and handle runtime errors gracefully without crashing the program. It uses try-except blocks to manage errors.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?
# - > The finally block executes regardless of whether an exception occurs or not. It's used for cleanup operations like closing files, database connections, or releasing resources.

# %% [markdown]
# 4. What is logging in Python?
# - > Logging is a way to track events and record messages during program execution. It's better than print statements for debugging and monitoring applications in production.

# %% [markdown]
# 5. What is the significance of the __del__ method in Python?
# - > The __del__ method is a destructor called when an object is about to be destroyed. However, it's not reliable for cleanup because:
# •	Timing is unpredictable
# •	May not be called in some situations
# •	Better to use context managers (with statement)

# %% [markdown]
# 6. What is the difference between import and from ... import in Python?
# - > •	Import module: Imports entire module, access via module.function()
#
# •	from module import function: Imports specific items directly into namespace
#
# •	**from module import ***: Imports all public items (not recommended)

# %% [markdown]
# 7. How can you handle multiple exceptions in Python?
# - > Answer:-

# %%
try:
    # risky code
    pass
except (ValueError, TypeError) as e:
    # Handle multiple exception types
    pass
except Exception as e:
    # Handle any other exception
    pass

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python?
# - > The with statement provides automatic resource management through context managers. It ensures files are properly closed even if an exception occurs, preventing resource leaks.

# %% [markdown]
# 9.  What is the difference between multithreading and multiprocessing?
# - >
# Multithreading:
#
# •	Shares memory space
#
# •	Lighter weight
#
# •	Limited by GIL in Python
#
# •	Good for I/O-bound tasks
#
# Multiprocessing:
#
# •	Separate memory spaces
#
# •	Heavier weight
#
# •	True parallelism
#
# •	Good for CPU-bound tasks

# %% [markdown]
# 10. What are the advantages of using logging in a program?
# - > •	Severity levels: Different message priorities (DEBUG, INFO, WARNING, ERROR, CRITICAL)
#
# •	Flexible output: Console, files, network, email.
#
# •	Performance: Can be disabled in production.
#
# •	Formatting: Timestamps, module names, line numbers.
#
# •	Filtering: Control what gets logged

# %% [markdown]
# 11. What is memory management in Python?
# - >Memory management in Python is handled automatically through:
#
# •	Reference counting: Tracks object references.
#
# •	Garbage collection: Removes unreachable objects.
#
# •	Memory pools: Efficient allocation for small objects

# %% [markdown]
# 12. What are the basic steps involved in exception handling in Python?
# - Try block: Contains code that might raise an exception
# -	Except block: Handles specific exceptions
# -	Else block: Executes if no exception occurs
# -	Finally block: Always executes for cleanup

# %% [markdown]
# 13. Why is memory management important in Python?
# -	Prevents memory leaks
# -	Optimizes performance
# -	Ensures efficient resource utilization
# -	Maintains program stability

# %% [markdown]
# 14. What is the role of try and except in exception handling?
# -	Try: Wraps potentially problematic code
# -	Except: Catches and handles specific exceptions, preventing program crashes

# %% [markdown]
# 15. How does Python's garbage collection system work?
# - >  Python uses:
# -	Reference counting: Immediate cleanup when reference count reaches zero.
# -	Cyclic garbage collector: Detects and cleans circular references.
# -	Generational collection: Objects are grouped by age for efficient collection.

# %% [markdown]
# 16. What is the purpose of the else block in exception handling?
# - > The else block executes only when no exception occurs in the try block. It's useful for code that should run only when the try block succeeds.

# %% [markdown]
# 17. What are the common logging levels in Python?
# -	DEBUG (10): Detailed diagnostic information.
# -	INFO (20): General information about program execution.
# -	WARNING (30): Something unexpected happened.
# -	ERROR (40): Serious problem occurred.
# -	CRITICAL (50): Very serious error occurred.

# %% [markdown]
# 18. What is the difference between os.fork() and multiprocessing in Python?
# -	os.fork(): Unix-specific system call that creates child processes.
# -	multiprocessing: Cross-platform module providing process-based parallelism with higher-level API.

# %% [markdown]
# 19. What is the importance of closing a file in Python?
# -	Frees system resources.
# -	Ensures data is written to disk (buffer flush).
# -	Prevents file corruption.
# -	Avoids "too many open files" errors.

# %% [markdown]
# 20. What is the difference between file.read() and file.readline() in Python?
# -	file.read(): Reads the entire file content as a single string.
# -	file.readline(): Reads one line at a time, returning a string with newline character.

# %% [markdown]
# 21. What is the logging module in Python used for?
# - > The logging module provides a flexible framework for emitting log messages from Python programs. It supports multiple handlers, formatters, and loggers with hierarchical organization.

# %% [markdown]
# 22. What is the os module in Python used for in file handling?
# - > The os module provides operating system interface functions for:
# -	File path operations
# -	Directory operations
# -	File operations
# -	Environment variables.

# %% [markdown]
# 23. What are the challenges associated with memory management in Python?
# -	Circular references can delay garbage collection.
# -	Large objects may fragment memory.
# -	Memory leaks from unclosed resources.
# - Global variables persist throughout program lifetime.
# -	C extensions may not follow Python's memory management.

# %% [markdown]
# 24. How do you raise an exception manually in Python?
# - raise ValueError("Custom error message")
#
# - raise Exception("General error")

# %% [markdown]
# 25. Why is it important to use multithreading in certain applications?
# -	I/O-bound tasks: While one thread waits for I/O, others can work.
# -	User interface: Keep UI responsive during background operations.
# -	Concurrent connections: Handle multiple clients simultaneously.
# -	Producer-consumer scenarios: Separate data generation and processing.

# %% [markdown]
# # PRACTICAL QUESTIONS

# %% [markdown]
# 1. How can you open a file for writing in Python and write a string to it?
# - > Answer:-

# %%
f = open('file.txt', 'w')
f.write("Hello, World!")
f.close()

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line.
# - > Answer:-

# %%
def read_file_lines(filename):
    try:
        with open(filename, 'r') as file:
            for line_number, line in enumerate(file, 1):
                print(f"Line {line_number}: {line.rstrip()}")
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except IOError:
        print(f"Error: Could not read file '{filename}'.")

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?
# - > Answer:-

# %%
def safe_read_file(filename):
    try:
        with open(filename, 'r') as file:
            return file.read()
    except FileNotFoundError:
        print(f"Error: File '{filename}' does not exist.")
        return None
    except PermissionError:
        print(f"Error: Permission denied to read '{filename}'.")
        return None
    except IOError as e:
        print(f"Error reading file: {e}")
        return None

# Usage
content = safe_read_file('nonexistent.txt')
# Out:
# Error: File 'nonexistent.txt' does not exist.

# %% [markdown]
# 4. Write a Python script that reads from one file and writes its content to another file.
# - > Answer:-

# %%
def copy_file(source_file, destination_file):
    try:
        with open(source_file, 'r') as src:
            with open(destination_file, 'w') as dst:
                dst.write(src.read())
        print(f"Successfully copied '{source_file}' to '{destination_file}'")
    except FileNotFoundError:
        print(f"Error: Source file '{source_file}' not found.")
    except IOError as e:
        print(f"Error during file operation: {e}")

# Usage
copy_file('source.txt', 'destination.txt')
# Out:
# Error: Source file 'source.txt' not found.

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python?
# - > Answer:-

# %%
def safe_division(dividend, divisor):
    try:
        result = dividend / divisor
        return result
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")
        return None
    except TypeError:
        print("Error: Invalid input types for division!")
        return None

# Usage
print(safe_division(10, 2))   # 5.0
print(safe_division(10, 0))   # Error message, returns None
# Out:
# 5.0
# Error: Cannot divide by zero!
# None

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.
# - > Answer:-

# %%
import logging

# Configure logging
logging.basicConfig(
    filename='error.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def division_with_logging(dividend, divisor):
    try:
        result = dividend / divisor
        logging.info(f"Division successful: {dividend} / {divisor} = {result}")
        return result
    except ZeroDivisionError as e:
        error_msg = f"Division by zero error: {dividend} / {divisor}"
        logging.error(error_msg)
        print(f"Error logged: {error_msg}")
        return None

# Usage
print(division_with_logging(10, 2))   # Successful division
print(division_with_logging(10, 0))   # Logs error
# Out:
# ERROR:root:Division by zero error: 10 / 0
# 5.0
# Error logged: Division by zero error: 10 / 0
# None

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
# - > Answer:-

# %%
import logging

# Configure logging to show all levels
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('app.log'),
        logging.StreamHandler()  # Also log to console
    ]
)

logger = logging.getLogger(__name__)

def demonstrate_logging_levels():
    logger.debug("This is a debug message - detailed diagnostic info")
    logger.info("This is an info message - general information")
    logger.warning("This is a warning message - something unexpected")
    logger.error("This is an error message - serious problem")
    logger.critical("This is a critical message - very serious error")

# Usage
demonstrate_logging_levels()

# Example with real application context
def process_user_data(user_data):
    logger.info("Starting user data processing")

    if not user_data:
        logger.warning("Empty user data received")
        return False

    try:
        # Simulate processing
        if 'email' not in user_data:
            logger.error("Missing required field: email")
            return False

        logger.info(f"Successfully processed user: {user_data.get('name', 'Unknown')}")
        return True

    except Exception as e:
        logger.critical(f"Critical error in user data processing: {e}")
        return False

# Usage
process_user_data({'name': 'John', 'email': 'john@email.com'})
process_user_data({'name': 'Jane'})  # Missing email
process_user_data({})  # Empty data
# Out:
# WARNING:__main__:This is a warning message - something unexpected
# ERROR:__main__:This is an error message - serious problem
# CRITICAL:__main__:This is a critical message - very serious error
# ERROR:__main__:Missing required field: email
# WARNING:__main__:Empty user data received
# False

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling.
# - > Answer:-

# %%
import logging

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

def safe_file_operation(filename, mode='r', content=None):
    """
    Safely perform file operations with comprehensive error handling
    """
    try:
        logger.info(f"Attempting to open file: {filename} in mode: {mode}")

        with open(filename, mode) as file:
            if mode in ['r', 'rt']:
                # Reading operations
                content = file.read()
                logger.info(f"Successfully read {len(content)} characters from {filename}")
                return content
            elif mode in ['w', 'wt', 'a', 'at']:
                # Writing operations
                if content is not None:
                    file.write(content)
                    logger.info(f"Successfully wrote content to {filename}")
                return True
            else:
                logger.warning(f"Unsupported file mode: {mode}")
                return None

    except FileNotFoundError:
        error_msg = f"File not found: {filename}"
        logger.error(error_msg)
        print(f"Error: {error_msg}")
        return None

    except PermissionError:
        error_msg = f"Permission denied: {filename}"
        logger.error(error_msg)
        print(f"Error: {error_msg}")
        return None

    except IsADirectoryError:
        error_msg = f"Expected file but found directory: {filename}"
        logger.error(error_msg)
        print(f"Error: {error_msg}")
        return None

    except OSError as e:
        error_msg = f"OS error occurred: {e}"
        logger.error(error_msg)
        print(f"Error: {error_msg}")
        return None

    except Exception as e:
        error_msg = f"Unexpected error: {e}"
        logger.error(error_msg)
        print(f"Error: {error_msg}")
        return None

# Usage examples
def demonstrate_file_error_handling():
    # Try to read a non-existent file
    content = safe_file_operation('nonexistent.txt', 'r')

    # Try to write to a file in a non-existent directory
    success = safe_file_operation('/invalid/path/file.txt', 'w', 'test content')

    # Try to read a valid file
    content = safe_file_operation('test.txt', 'r')

    # Create a test file and read it
    if safe_file_operation('test_output.txt', 'w', 'Hello, World!'):
        content = safe_file_operation('test_output.txt', 'r')
        print(f"File content: {content}")

# Run demonstration
demonstrate_file_error_handling()
# Out:
# ERROR:__main__:File not found: nonexistent.txt
# ERROR:__main__:File not found: /invalid/path/file.txt
# ERROR:__main__:File not found: test.txt
# Error: File not found: nonexistent.txt
# Error: File not found: /invalid/path/file.txt
# Error: File not found: test.txt
# File content: Hello, World!

# %% [markdown]
# 9. How can you read a file line by line and store its content in a list in Python?
# - > Answer:-

# %%
def file_to_list(filename):
    try:
        with open(filename, 'r') as file:
            lines = [line.rstrip() for line in file]
        return lines
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return []

# Alternative method
def file_to_list_alternative(filename):
    try:
        with open(filename, 'r') as file:
            lines = file.readlines()
        return [line.rstrip() for line in lines]
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return []

# Usage
lines = file_to_list('data.txt')
print(lines)
# Out:
# Error: File 'data.txt' not found.
# []

# %% [markdown]
# 10. How can you append data to an existing file in Python?
# - > Answer:-

# %%
def append_to_file(filename, data):
    try:
        with open(filename, 'a') as file:
            file.write(data + '\n')
        print(f"Data appended to '{filename}' successfully.")
    except IOError as e:
        print(f"Error appending to file: {e}")

# Usage
append_to_file('log.txt', 'New log entry')
# Out:
# Data appended to 'log.txt' successfully.

# %% [markdown]
# 11.  Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist.
# - > Answer:-

# %%
def safe_dict_access(dictionary, key):
    try:
        value = dictionary[key]
        print(f"Value for key '{key}': {value}")
        return value
    except KeyError:
        print(f"Error: Key '{key}' not found in dictionary!")
        return None

# Alternative using get() method
def safe_dict_get(dictionary, key, default=None):
    value = dictionary.get(key, default)
    if value is None and key not in dictionary:
        print(f"Key '{key}' not found, returning default value")
    return value

# Usage
my_dict = {'a': 1, 'b': 2, 'c': 3}
safe_dict_access(my_dict, 'a')    # Works
safe_dict_access(my_dict, 'z')    # KeyError handled
# Out:
# Value for key 'a': 1
# Error: Key 'z' not found in dictionary!

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.
# - > Answer:-

# %%
def demonstrate_multiple_exceptions(data, index, key):
    try:
        # This could raise multiple types of exceptions
        if isinstance(data, list):
            value = data[index]  # Could raise IndexError
        elif isinstance(data, dict):
            value = data[key]    # Could raise KeyError
        else:
            value = int(data)    # Could raise ValueError

        result = 100 / value     # Could raise ZeroDivisionError
        print(f"Result: {result}")
        return result

    except IndexError:
        print("Error: List index out of range!")
        return None
    except KeyError:
        print(f"Error: Key '{key}' not found in dictionary!")
        return None
    except ValueError:
        print("Error: Cannot convert to integer!")
        return None
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")
        return None
    except TypeError:
        print("Error: Invalid data type!")
        return None

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?
# - > Answer:-

# %%
def safe_file_read(filename):
    if os.path.exists(filename):
        try:
            with open(filename, 'r') as file:
                return file.read()
        except IOError as e:
            print(f"Error reading file: {e}")
            return None
    else:
        print(f"File '{filename}' does not exist.")
        return None

# Alternative using pathlib (Python 3.4+)
from pathlib import Path

def safe_file_read_pathlib(filename):
    file_path = Path(filename)
    if file_path.exists():
        try:
            return file_path.read_text()
        except IOError as e:
            print(f"Error reading file: {e}")
            return None
    else:
        print(f"File '{filename}' does not exist.")
        return None

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages.
# - > Answer:-

# %%
import logging
import os

def setup_logging():
    # Create logs directory if it doesn't exist
    if not os.path.exists('logs'):
        os.makedirs('logs')

    # Configure logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler('logs/application.log'),
            logging.StreamHandler()
        ]
    )
    return logging.getLogger(__name__)

def file_processor(filename):
    logger = setup_logging()

    logger.info(f"Starting file processing for: {filename}")

    try:
        if not os.path.exists(filename):
            logger.error(f"File not found: {filename}")
            return False

        with open(filename, 'r') as file:
            lines = file.readlines()

        logger.info(f"Successfully read {len(lines)} lines from {filename}")

        # Process each line
        processed_count = 0
        for line_num, line in enumerate(lines, 1):
            try:
                # Simulate processing
                if line.strip():  # Non-empty line
                    processed_count += 1
                    logger.debug(f"Processed line {line_num}: {line.strip()[:20]}...")
            except Exception as e:
                logger.error(f"Error processing line {line_num}: {e}")

        logger.info(f"Processing completed. {processed_count} lines processed successfully")
        return True

    except IOError as e:
        logger.error(f"IO error while processing {filename}: {e}")
        return False
    except Exception as e:
        logger.error(f"Unexpected error: {e}")
        return False
    finally:
        logger.info("File processing finished")

# Usage
file_processor('sample.txt')
# Out:
# ERROR:__main__:File not found: sample.txt
# False

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.
# - > Answer:-

# %%
import os

def print_file_content_safe(filename):
    """
    Print file content with proper handling of empty files and errors
    """
    try:
        # Check if file exists
        if not os.path.exists(filename):
            print(f"Error: File '{filename}' does not exist.")
            return False

        # Check if file is empty
        file_size = os.path.getsize(filename)
        if file_size == 0:
            print(f"File '{filename}' is empty.")
            return True

        # Read and print file content
        with open(filename, 'r') as file:
            content = file.read()

        print(f"Content of '{filename}':")
        print("-" * 40)
        print(content)
        print("-" * 40)
        print(f"File size: {file_size} bytes")
        return True

    except PermissionError:
        print(f"Error: Permission denied to read '{filename}'.")
        return False
    except UnicodeDecodeError:
        print(f"Error: Cannot decode '{filename}' as text file.")
        return False
    except IOError as e:
        print(f"Error reading file '{filename}': {e}")
        return False

# Alternative version with line-by-line printing
def print_file_lines_safe(filename):
    """
    Print file content line by line with line numbers
    """
    try:
        if not os.path.exists(filename):
            print(f"Error: File '{filename}' does not exist.")
            return False

        if os.path.getsize(filename) == 0:
            print(f"File '{filename}' is empty.")
            return True

        with open(filename, 'r') as file:
            lines = file.readlines()

        print(f"Content of '{filename}' ({len(lines)} lines):")
        print("-" * 40)

        for line_num, line in enumerate(lines, 1):
            print(f"{line_num:3}: {line.rstrip()}")

        print("-" * 40)
        return True

    except Exception as e:
        print(f"Error processing file '{filename}': {e}")
        return False

# Usage and testing
def test_file_printing():
    # Test with different scenarios

    # Create test files
    test_files = {
        'empty.txt': '',
        'small.txt': 'Hello\nWorld\n',
        'multiline.txt': '\n'.join([f'Line {i}' for i in range(1, 6)])
    }

    for filename, content in test_files.items():
        with open(filename, 'w') as f:
            f.write(content)

    # Test printing
    for filename in test_files.keys():
        print(f"\n=== Testing {filename} ===")
        print_file_content_safe(filename)

    # Test with non-existent file
    print(f"\n=== Testing non-existent file ===")
    print_file_content_safe('does_not_exist.txt')

# Run tests
test_file_printing()
# Out:
# === Testing empty.txt ===
# File 'empty.txt' is empty.
#
# === Testing small.txt ===
# Content of 'small.txt':
# ----------------------------------------
# Hello
# World
#
# ----------------------------------------
# File size: 12 bytes
#
# === Testing multiline.txt ===
# Content of 'multiline.txt':
# ----------------------------------------
# Line 1
# Line 2
# Line 3
# Line 4
# Line 5
# ----------------------------------------
# File size: 34 bytes
#
# === Testing non-existent file ===
# Error: File 'does_not_exist.txt' does not exist.

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.
# - > Answer:-

# %%
def memory_profiling_with_tracemalloc():
    print("=== Memory Profiling with tracemalloc ===")

    # Start tracing
    tracemalloc.start()

    # Take a snapshot before operations
    snapshot1 = tracemalloc.take_snapshot()

    # Create some data structures
    data = []
    for i in range(10000):
        data.append(f"String number {i}" * 10)

    # Take snapshot after operations
    snapshot2 = tracemalloc.take_snapshot()

    # Compare snapshots
    top_stats = snapshot2.compare_to(snapshot1, 'lineno')

    print("Top 10 memory allocations:")
    for stat in top_stats[:10]:
        print(stat)

    # Current memory usage
    current, peak = tracemalloc.get_traced_memory()
    print(f"\nCurrent memory usage: {current / 1024 / 1024:.2f} MB")
    print(f"Peak memory usage: {peak / 1024 / 1024:.2f} MB")

# %%
def memory_intensive_function():
    """Function decorated with @profile for line-by-line memory analysis"""
    data = []

    # Create large list
    for i in range(50000):
        data.append(i ** 2)

    # Create dictionary
    lookup = {i: f"value_{i}" for i in range(10000)}

    # Process data
    result = [x * 2 for x in data if x % 2 == 0]

    return result, lookup

# %%
def __init__(self):
        self.process = psutil.Process(os.getpid())

# %%
def get_memory_usage(self):
        """Get current memory usage in MB"""
        memory_info = self.process.memory_info()
        return {
            'rss': memory_info.rss / 1024 / 1024,  # Resident Set Size
            'vms': memory_info.vms / 1024 / 1024,  # Virtual Memory Size
        }

# %%
def monitor_function(self, func, *args, **kwargs):
        """Monitor memory usage of a function"""
        print(f"\n=== Monitoring function: {func.__name__} ===")

        # Memory before
        memory_before = self.get_memory_usage()
        print(f"Memory before: RSS={memory_before['rss']:.2f}MB, VMS={memory_before['vms']:.2f}MB")

        # Execute function
        result = func(*args, **kwargs)

        # Memory after
        memory_after = self.get_memory_usage()
        print(f"Memory after: RSS={memory_after['rss']:.2f}MB, VMS={memory_after['vms']:.2f}MB")

        # Memory difference
        rss_diff = memory_after['rss'] - memory_before['rss']
        vms_diff = memory_after['vms'] - memory_before['vms']
        print(f"Memory difference: RSS={rss_diff:+.2f}MB, VMS={vms_diff:+.2f}MB")

        return result

# Method 4: Context manager for memory monitoring
class MemoryProfiler:
    def __init__(self, description="Memory usage"):
        self.description = description
        self.start_memory = None

    def __enter__(self):
        gc.collect()  # Force garbage collection
        self.start_memory = self._get_memory()
        print(f"\n{self.description} - Start: {self.start_memory:.2f} MB")
        return self

# %%
def __exit__(self, exc_type, exc_val, exc_tb):
        gc.collect()  # Force garbage collection
        end_memory = self._get_memory()
        diff = end_memory - self.start_memory
        print(f"{self.description} - End: {end_memory:.2f} MB")
        print(f"{self.description} - Difference: {diff:+.2f} MB")

# %%
    def _get_memory(self):
        """Get current memory usage in MB"""
        return psutil.Process().memory_info().rss / 1024 / 1024

# %%
def create_large_list(size=100000):
    """Create a large list"""
    return [i ** 2 for i in range(size)]

# %%
def create_large_dict(size=50000):
    """Create a large dictionary"""
    return {f"key_{i}": f"value_{i}" * 10 for i in range(size)}

# %%
def process_data(data):
    """Process data and create new structures"""
    # Filter even numbers
    evens = [x for x in data if x % 2 == 0]

    # Create lookup dictionary
    lookup = {x: x ** 0.5 for x in evens[:10000]}

    return evens, lookup

# %%
def demonstrate_memory_profiling():
    print("Memory Profiling Demonstration")
    print("=" * 50)

# %%
    data = memory_profiling_with_tracemalloc()
# Out:
# === Memory Profiling with tracemalloc ===
# Top 10 memory allocations:
# /tmp/ipython-input-3070225368.py:13: size=2230 KiB (+2230 KiB), count=10001 (+10001), average=228 B
# /usr/lib/python3.12/tracemalloc.py:558: size=8656 B (+7976 B), count=180 (+166), average=48 B
# /usr/lib/python3.12/tracemalloc.py:193: size=6720 B (-7728 B), count=140 (-161), average=48 B
# /usr/local/lib/python3.12/dist-packages/zmq/utils/jsonapi.py:25: size=2400 B (-1453 B), count=20 (-10), average=120 B
# /usr/lib/python3.12/threading.py:293: size=760 B (-760 B), count=2 (-2), average=380 B
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py:286: size=720 B (-416 B), count=6 (-9), average=120 B
# /usr/lib/python3.12/threading.py:290: size=344 B (-344 B), count=3 (-3), average=115 B
# /usr/lib/python3.12/tracemalloc.py:560: size=280 B (+280 B), count=2 (+2), average=140 B
# /usr/lib/python3.12/tracemalloc.py:423: size=280 B (+280 B), count=2 (+2), average=140 B
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py:219: size=840 B (-264 B), count=7 (-2), average=120 B
#
# Current memory usage: 2.42 MB
# Peak memory usage: 2.46 MB

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.
# - > Answer:-

# %%
def write_numbers_to_file(numbers, filename):
    try:
        with open(filename, 'w') as file:
            for number in numbers:
                file.write(f"{number}\n")
        print(f"Numbers written to '{filename}' successfully.")
    except IOError as e:
        print(f"Error writing to file: {e}")

# Alternative using join
def write_numbers_join(numbers, filename):
    try:
        with open(filename, 'w') as file:
            file.write('\n'.join(map(str, numbers)) + '\n')
        print(f"Numbers written to '{filename}' successfully.")
    except IOError as e:
        print(f"Error writing to file: {e}")

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?
# - > Answer:-

# %%
import logging
from logging.handlers import RotatingFileHandler
import os

def setup_rotating_logger(name, log_file, max_bytes=1024*1024, backup_count=5):
    """
    Setup a logger with rotating file handler
    max_bytes: Maximum size before rotation (default 1MB)
    backup_count: Number of backup files to keep
    """

    # Create logs directory if it doesn't exist
    log_dir = os.path.dirname(log_file)
    if log_dir and not os.path.exists(log_dir):
        os.makedirs(log_dir)

    # Create logger
    logger = logging.getLogger(name)
    logger.setLevel(logging.INFO)

    # Create rotating file handler
    handler = RotatingFileHandler(
        log_file,
        maxBytes=max_bytes,
        backupCount=backup_count
    )

    # Create formatter
    formatter = logging.Formatter(
        '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
    )
    handler.setFormatter(formatter)

    # Add handler to logger
    logger.addHandler(handler)

    return logger

# Usage example
def application_with_rotating_logs():
    logger = setup_rotating_logger(
        'MyApp',
        'logs/rotating_app.log',
        max_bytes=1024*1024,  # 1MB
        backup_count=3
    )

    # Simulate application activity
    for i in range(1000):
        logger.info(f"Processing item {i}")
        logger.warning(f"Warning for item {i}")
        if i % 100 == 0:
            logger.error(f"Error processing batch at item {i}")

# Run the application
application_with_rotating_logs()
# Out:
# INFO:MyApp:Processing item 0
# WARNING:MyApp:Warning for item 0
# ERROR:MyApp:Error processing batch at item 0
# INFO:MyApp:Processing item 1
# WARNING:MyApp:Warning for item 1
# INFO:MyApp:Processing item 2
# WARNING:MyApp:Warning for item 2
# INFO:MyApp:Processing item 3
# WARNING:MyApp:Warning for item 3
# INFO:MyApp:Processing item 4
# WARNING:MyApp:Warning for item 4
# INFO:MyApp:Processing item 5
# WARNING:MyApp:Warning for item 5
# INFO:MyApp:Processing item 6
# WARNING:MyApp:Warning for item 6
# INFO:MyApp:Processing item 7
# WARNING:MyApp:Warning for item 7
# INFO:MyApp:Processing item 8
# WARNING:MyApp:Warning for item 8
# INFO:MyApp:Processing item 9
# WARNING:MyApp:Warning for item 9
# INFO:MyApp:Processing item 10
# WARNING:MyApp:Warning for item 10
# INFO:MyApp:Processing item 11
# WARNING:MyApp:Warning for item 11
# INFO:MyApp:Processing item 12
# WARNING:MyApp:Warning for item 12
# INFO:MyApp:Processing item 13
# WARNING:MyApp:Warning for item 13
# INFO:MyApp:Processing item 14
# WARNING:MyApp:Warning for item 14
# INFO:MyApp:Processing item 15
# WARNING:MyApp:Warning for item 15
# INFO:MyApp:Processing item 16
# WARNING:MyApp:Warning for item 16
# INFO:MyApp:Processing item 17
# WARNING:MyApp:Warning for item 17
# INFO:MyApp:Processing item 18
# WARNING:MyApp:Warning for item 18
# INFO:MyApp:Processing item 19
# WARNING:MyApp:Warning for item 19
# INFO:MyApp:Processing item 20
# WARNING:MyApp:Warning for item 20
# INFO:MyApp:Processing item 21
# WARNING:MyApp:Warning for item 21
# INFO:MyApp:Processing item 22
# WARNING:MyApp:Warning for item 22
# INFO:MyApp:Processing item 23
# WARNING:MyApp:Warning for item 23
# INFO:MyApp:Processing item 24
# WARNING:MyApp:Warning for item 24
# INFO:MyApp:Processing item 25
# WARNING:MyApp:Warning for item 25
# INFO:MyApp:Processing item 26
# WARNING:MyApp:Warning for item 26
# INFO:MyApp:Processing item 27
# WARNING:MyApp:Warning for item 27
# INFO:MyApp:Processing item 28
# WARNING:MyApp:Warning for item 28
# INFO:MyApp:Processing item 29
# WARNING:MyApp:Warning for item 29
# INFO:MyApp:Processing item 30
# WARNING:MyApp:Warning for item 30
# INFO:MyApp:Processing item 31
# WARNING:MyApp:Warning for item 31
# INFO:MyApp:Processing item 32
# WARNING:MyApp:Warning for item 32
# INFO:MyApp:Processing item 33
# WARNING:MyApp:Warning for item 33
# INFO:MyApp:Processing item 34
# WARNING:MyApp:Warning for item 34
# INFO:MyApp:Processing item 35
# WARNING:MyApp:Warning for item 35
# INFO:MyApp:Processing item 36
# WARNING:MyApp:Warning for item 36
# INFO:MyApp:Processing item 37
# WARNING:MyApp:Warning for item 37
# INFO:MyApp:Processing item 38
# WARNING:MyApp:Warning for item 38
# INFO:MyApp:Processing item 39
# WARNING:MyApp:Warning for item 39
# INFO:MyApp:Processing item 40
# WARNING:MyApp:Warning for item 40
# INFO:MyApp:Processing item 41
# WARNING:MyApp:Warning for item 41
# INFO:MyApp:Processing item 42
# WARNING:MyApp:Warning for item 42
# INFO:MyApp:Processing item 43
# WARNING:MyApp:Warning for item 43
# INFO:MyApp:Processing item 44
# WARNING:MyApp:Warning for item 44
# INFO:MyApp:Processing item 45
# WARNING:MyApp:Warning for item 45
# INFO:MyApp:Processing item 46
# WARNING:MyApp:Warning for item 46
# INFO:MyApp:Processing item 47
# WARNING:MyApp:Warning for item 47
# INFO:MyApp:Processing item 48
# WARNING:MyApp:Warning for item 48
# INFO:MyApp:Processing item 49
# WARNING:MyApp:Warning for item 49
# INFO:MyApp:Processing item 50
# WARNING:MyApp:Warning for item 50
# INFO:MyApp:Processing item 51
# WARNING:MyApp:Warning for item 51
# INFO:MyApp:Processing item 52
# WARNING:MyApp:Warning for item 52
# INFO:MyApp:Processing item 53
# WARNING:MyApp:Warning for item 53
# INFO:MyApp:Processing item 54
# WARNING:MyApp:Warning for item 54
# INFO:MyApp:Processing item 55
# WARNING:MyApp:Warning for item 55
# INFO:MyApp:Processing item 56
# WARNING:MyApp:Warning for item 56
# INFO:MyApp:Processing item 57
# WARNING:MyApp:Warning for item 57
# INFO:MyApp:Processing item 58
# WARNING:MyApp:Warning for item 58
# INFO:MyApp:Processing item 59
# WARNING:MyApp:Warning for item 59
# INFO:MyApp:Processing item 60
# WARNING:MyApp:Warning for item 60
# INFO:MyApp:Processing item 61
# WARNING:MyApp:Warning for item 61
# INFO:MyApp:Processing item 62
# WARNING:MyApp:Warning for item 62
# INFO:MyApp:Processing item 63
# WARNING:MyApp:Warning for item 63
# INFO:MyApp:Processing item 64
# WARNING:MyApp:Warning for item 64
# INFO:MyApp:Processing item 65
# WARNING:MyApp:Warning for item 65
# INFO:MyApp:Processing item 66
# WARNING:MyApp:Warning for item 66
# INFO:MyApp:Processing item 67
# WARNING:MyApp:Warning for item 67
# INFO:MyApp:Processing item 68
# WARNING:MyApp:Warning for item 68
# INFO:MyApp:Processing item 69
# WARNING:MyApp:Warning for item 69
# INFO:MyApp:Processing item 70
# WARNING:MyApp:Warning for item 70
# INFO:MyApp:Processing item 71
# WARNING:MyApp:Warning for item 71
# INFO:MyApp:Processing item 72
# WARNING:MyApp:Warning for item 72
# INFO:MyApp:Processing item 73
# WARNING:MyApp:Warning for item 73
# INFO:MyApp:Processing item 74
# WARNING:MyApp:Warning for item 74
# INFO:MyApp:Processing item 75
# WARNING:MyApp:Warning for item 75
# INFO:MyApp:Processing item 76
# WARNING:MyApp:Warning for item 76
# INFO:MyApp:Processing item 77
# WARNING:MyApp:Warning for item 77
# INFO:MyApp:Processing item 78
# WARNING:MyApp:Warning for item 78
# INFO:MyApp:Processing item 79
# WARNING:MyApp:Warning for item 79
# INFO:MyApp:Processing item 80
# WARNING:MyApp:Warning for item 80
# INFO:MyApp:Processing item 81
# WARNING:MyApp:Warning for item 81
# INFO:MyApp:Processing item 82
# WARNING:MyApp:Warning for item 82
# INFO:MyApp:Processing item 83
# WARNING:MyApp:Warning for item 83
# INFO:MyApp:Processing item 84
# WARNING:MyApp:Warning for item 84
# INFO:MyApp:Processing item 85
# WARNING:MyApp:Warning for item 85
# INFO:MyApp:Processing item 86
# WARNING:MyApp:Warning for item 86
# INFO:MyApp:Processing item 87
# WARNING:MyApp:Warning for item 87
# INFO:MyApp:Processing item 88
# WARNING:MyApp:Warning for item 88
# INFO:MyApp:Processing item 89
# WARNING:MyApp:Warning for item 89
# INFO:MyApp:Processing item 90
# WARNING:MyApp:Warning for item 90
# INFO:MyApp:Processing item 91
# WARNING:MyApp:Warning for item 91
# INFO:MyApp:Processing item 92
# WARNING:MyApp:Warning for item 92
# INFO:MyApp:Processing item 93
# WARNING:MyApp:Warning for item 93
# INFO:MyApp:Processing item 94
# WARNING:MyApp:Warning for item 94
# INFO:MyApp:Processing item 95
# WARNING:MyApp:Warning for item 95
# INFO:MyApp:Processing item 96
# WARNING:MyApp:Warning for item 96
# INFO:MyApp:Processing item 97
# WARNING:MyApp:Warning for item 97
# INFO:MyApp:Processing item 98
# WARNING:MyApp:Warning for item 98
# INFO:MyApp:Processing item 99
# WARNING:MyApp:Warning for item 99
# INFO:MyApp:Processing item 100
# WARNING:MyApp:Warning for item 100
# ERROR:MyApp:Error processing batch at item 100
# INFO:MyApp:Processing item 101
# WARNING:MyApp:Warning for item 101
# INFO:MyApp:Processing item 102
# WARNING:MyApp:Warning for item 102
# INFO:MyApp:Processing item 103
# WARNING:MyApp:Warning for item 103
# INFO:MyApp:Processing item 104
# WARNING:MyApp:Warning for item 104
# INFO:MyApp:Processing item 105
# WARNING:MyApp:Warning for item 105
# INFO:MyApp:Processing item 106
# WARNING:MyApp:Warning for item 106
# INFO:MyApp:Processing item 107
# WARNING:MyApp:Warning for item 107
# INFO:MyApp:Processing item 108
# WARNING:MyApp:Warning for item 108
# INFO:MyApp:Processing item 109
# WARNING:MyApp:Warning for item 109
# INFO:MyApp:Processing item 110
# WARNING:MyApp:Warning for item 110
# INFO:MyApp:Processing item 111
# WARNING:MyApp:Warning for item 111
# INFO:MyApp:Processing item 112
# WARNING:MyApp:Warning for item 112
# INFO:MyApp:Processing item 113
# WARNING:MyApp:Warning for item 113
# INFO:MyApp:Processing item 114
# WARNING:MyApp:Warning for item 114
# INFO:MyApp:Processing item 115
# WARNING:MyApp:Warning for item 115
# INFO:MyApp:Processing item 116
# WARNING:MyApp:Warning for item 116
# INFO:MyApp:Processing item 117
# WARNING:MyApp:Warning for item 117
# INFO:MyApp:Processing item 118
# WARNING:MyApp:Warning for item 118
# INFO:MyApp:Processing item 119
# WARNING:MyApp:Warning for item 119
# INFO:MyApp:Processing item 120
# WARNING:MyApp:Warning for item 120
# INFO:MyApp:Processing item 121
# WARNING:MyApp:Warning for item 121
# INFO:MyApp:Processing item 122
# WARNING:MyApp:Warning for item 122
# INFO:MyApp:Processing item 123
# WARNING:MyApp:Warning for item 123
# INFO:MyApp:Processing item 124
# WARNING:MyApp:Warning for item 124
# INFO:MyApp:Processing item 125
# WARNING:MyApp:Warning for item 125
# INFO:MyApp:Processing item 126
# WARNING:MyApp:Warning for item 126
# INFO:MyApp:Processing item 127
# WARNING:MyApp:Warning for item 127
# INFO:MyApp:Processing item 128
# WARNING:MyApp:Warning for item 128
# INFO:MyApp:Processing item 129
# WARNING:MyApp:Warning for item 129
# INFO:MyApp:Processing item 130
# WARNING:MyApp:Warning for item 130
# INFO:MyApp:Processing item 131
# WARNING:MyApp:Warning for item 131
# INFO:MyApp:Processing item 132
# WARNING:MyApp:Warning for item 132
# INFO:MyApp:Processing item 133
# WARNING:MyApp:Warning for item 133
# INFO:MyApp:Processing item 134
# WARNING:MyApp:Warning for item 134
# INFO:MyApp:Processing item 135
# WARNING:MyApp:Warning for item 135
# INFO:MyApp:Processing item 136
# WARNING:MyApp:Warning for item 136
# INFO:MyApp:Processing item 137
# WARNING:MyApp:Warning for item 137
# INFO:MyApp:Processing item 138
# WARNING:MyApp:Warning for item 138
# INFO:MyApp:Processing item 139
# WARNING:MyApp:Warning for item 139
# INFO:MyApp:Processing item 140
# WARNING:MyApp:Warning for item 140
# INFO:MyApp:Processing item 141
# WARNING:MyApp:Warning for item 141
# INFO:MyApp:Processing item 142
# WARNING:MyApp:Warning for item 142
# INFO:MyApp:Processing item 143
# WARNING:MyApp:Warning for item 143
# INFO:MyApp:Processing item 144
# WARNING:MyApp:Warning for item 144
# INFO:MyApp:Processing item 145
# WARNING:MyApp:Warning for item 145
# INFO:MyApp:Processing item 146
# WARNING:MyApp:Warning for item 146
# INFO:MyApp:Processing item 147
# WARNING:MyApp:Warning for item 147
# INFO:MyApp:Processing item 148
# WARNING:MyApp:Warning for item 148
# INFO:MyApp:Processing item 149
# WARNING:MyApp:Warning for item 149
# INFO:MyApp:Processing item 150
# WARNING:MyApp:Warning for item 150
# INFO:MyApp:Processing item 151
# WARNING:MyApp:Warning for item 151
# INFO:MyApp:Processing item 152
# WARNING:MyApp:Warning for item 152
# INFO:MyApp:Processing item 153
# WARNING:MyApp:Warning for item 153
# INFO:MyApp:Processing item 154
# WARNING:MyApp:Warning for item 154
# INFO:MyApp:Processing item 155
# WARNING:MyApp:Warning for item 155
# INFO:MyApp:Processing item 156
# WARNING:MyApp:Warning for item 156
# INFO:MyApp:Processing item 157
# WARNING:MyApp:Warning for item 157
# INFO:MyApp:Processing item 158
# WARNING:MyApp:Warning for item 158
# INFO:MyApp:Processing item 159
# WARNING:MyApp:Warning for item 159
# INFO:MyApp:Processing item 160
# WARNING:MyApp:Warning for item 160
# INFO:MyApp:Processing item 161
# WARNING:MyApp:Warning for item 161
# INFO:MyApp:Processing item 162
# WARNING:MyApp:Warning for item 162
# INFO:MyApp:Processing item 163
# WARNING:MyApp:Warning for item 163
# INFO:MyApp:Processing item 164
# WARNING:MyApp:Warning for item 164
# INFO:MyApp:Processing item 165
# WARNING:MyApp:Warning for item 165
# INFO:MyApp:Processing item 166
# WARNING:MyApp:Warning for item 166
# INFO:MyApp:Processing item 167
# WARNING:MyApp:Warning for item 167
# INFO:MyApp:Processing item 168
# WARNING:MyApp:Warning for item 168
# INFO:MyApp:Processing item 169
# WARNING:MyApp:Warning for item 169
# INFO:MyApp:Processing item 170
# WARNING:MyApp:Warning for item 170
# INFO:MyApp:Processing item 171
# WARNING:MyApp:Warning for item 171
# INFO:MyApp:Processing item 172
# WARNING:MyApp:Warning for item 172
# INFO:MyApp:Processing item 173
# WARNING:MyApp:Warning for item 173
# INFO:MyApp:Processing item 174
# WARNING:MyApp:Warning for item 174
# INFO:MyApp:Processing item 175
# WARNING:MyApp:Warning for item 175
# INFO:MyApp:Processing item 176
# WARNING:MyApp:Warning for item 176
# INFO:MyApp:Processing item 177
# WARNING:MyApp:Warning for item 177
# INFO:MyApp:Processing item 178
# WARNING:MyApp:Warning for item 178
# INFO:MyApp:Processing item 179
# WARNING:MyApp:Warning for item 179
# INFO:MyApp:Processing item 180
# WARNING:MyApp:Warning for item 180
# INFO:MyApp:Processing item 181
# WARNING:MyApp:Warning for item 181
# INFO:MyApp:Processing item 182
# WARNING:MyApp:Warning for item 182
# INFO:MyApp:Processing item 183
# WARNING:MyApp:Warning for item 183
# INFO:MyApp:Processing item 184
# WARNING:MyApp:Warning for item 184
# INFO:MyApp:Processing item 185
# WARNING:MyApp:Warning for item 185
# INFO:MyApp:Processing item 186
# WARNING:MyApp:Warning for item 186
# INFO:MyApp:Processing item 187
# WARNING:MyApp:Warning for item 187
# INFO:MyApp:Processing item 188
# WARNING:MyApp:Warning for item 188
# INFO:MyApp:Processing item 189
# WARNING:MyApp:Warning for item 189
# INFO:MyApp:Processing item 190
# WARNING:MyApp:Warning for item 190
# INFO:MyApp:Processing item 191
# WARNING:MyApp:Warning for item 191
# INFO:MyApp:Processing item 192
# WARNING:MyApp:Warning for item 192
# INFO:MyApp:Processing item 193
# WARNING:MyApp:Warning for item 193
# INFO:MyApp:Processing item 194
# WARNING:MyApp:Warning for item 194
# INFO:MyApp:Processing item 195
# WARNING:MyApp:Warning for item 195
# INFO:MyApp:Processing item 196
# WARNING:MyApp:Warning for item 196
# INFO:MyApp:Processing item 197
# WARNING:MyApp:Warning for item 197
# INFO:MyApp:Processing item 198
# WARNING:MyApp:Warning for item 198
# INFO:MyApp:Processing item 199
# WARNING:MyApp:Warning for item 199
# INFO:MyApp:Processing item 200
# WARNING:MyApp:Warning for item 200
# ERROR:MyApp:Error processing batch at item 200
# INFO:MyApp:Processing item 201
# WARNING:MyApp:Warning for item 201
# INFO:MyApp:Processing item 202
# WARNING:MyApp:Warning for item 202
# INFO:MyApp:Processing item 203
# WARNING:MyApp:Warning for item 203
# INFO:MyApp:Processing item 204
# WARNING:MyApp:Warning for item 204
# INFO:MyApp:Processing item 205
# WARNING:MyApp:Warning for item 205
# INFO:MyApp:Processing item 206
# WARNING:MyApp:Warning for item 206
# INFO:MyApp:Processing item 207
# WARNING:MyApp:Warning for item 207
# INFO:MyApp:Processing item 208
# WARNING:MyApp:Warning for item 208
# INFO:MyApp:Processing item 209
# WARNING:MyApp:Warning for item 209
# INFO:MyApp:Processing item 210
# WARNING:MyApp:Warning for item 210
# INFO:MyApp:Processing item 211
# WARNING:MyApp:Warning for item 211
# INFO:MyApp:Processing item 212
# WARNING:MyApp:Warning for item 212
# INFO:MyApp:Processing item 213
# WARNING:MyApp:Warning for item 213
# INFO:MyApp:Processing item 214
# WARNING:MyApp:Warning for item 214
# INFO:MyApp:Processing item 215
# WARNING:MyApp:Warning for item 215
# INFO:MyApp:Processing item 216
# WARNING:MyApp:Warning for item 216
# INFO:MyApp:Processing item 217
# WARNING:MyApp:Warning for item 217
# INFO:MyApp:Processing item 218
# WARNING:MyApp:Warning for item 218
# INFO:MyApp:Processing item 219
# WARNING:MyApp:Warning for item 219
# INFO:MyApp:Processing item 220
# WARNING:MyApp:Warning for item 220
# INFO:MyApp:Processing item 221
# WARNING:MyApp:Warning for item 221
# INFO:MyApp:Processing item 222
# WARNING:MyApp:Warning for item 222
# INFO:MyApp:Processing item 223
# WARNING:MyApp:Warning for item 223
# INFO:MyApp:Processing item 224
# WARNING:MyApp:Warning for item 224
# INFO:MyApp:Processing item 225
# WARNING:MyApp:Warning for item 225
# INFO:MyApp:Processing item 226
# WARNING:MyApp:Warning for item 226
# INFO:MyApp:Processing item 227
# WARNING:MyApp:Warning for item 227
# INFO:MyApp:Processing item 228
# WARNING:MyApp:Warning for item 228
# INFO:MyApp:Processing item 229
# WARNING:MyApp:Warning for item 229
# INFO:MyApp:Processing item 230
# WARNING:MyApp:Warning for item 230
# INFO:MyApp:Processing item 231
# WARNING:MyApp:Warning for item 231
# INFO:MyApp:Processing item 232
# WARNING:MyApp:Warning for item 232
# INFO:MyApp:Processing item 233
# WARNING:MyApp:Warning for item 233
# INFO:MyApp:Processing item 234
# WARNING:MyApp:Warning for item 234
# INFO:MyApp:Processing item 235
# WARNING:MyApp:Warning for item 235
# INFO:MyApp:Processing item 236
# WARNING:MyApp:Warning for item 236
# INFO:MyApp:Processing item 237
# WARNING:MyApp:Warning for item 237
# INFO:MyApp:Processing item 238
# WARNING:MyApp:Warning for item 238
# INFO:MyApp:Processing item 239
# WARNING:MyApp:Warning for item 239
# INFO:MyApp:Processing item 240
# WARNING:MyApp:Warning for item 240
# INFO:MyApp:Processing item 241
# WARNING:MyApp:Warning for item 241
# INFO:MyApp:Processing item 242
# WARNING:MyApp:Warning for item 242
# INFO:MyApp:Processing item 243
# WARNING:MyApp:Warning for item 243
# INFO:MyApp:Processing item 244
# WARNING:MyApp:Warning for item 244
# INFO:MyApp:Processing item 245
# WARNING:MyApp:Warning for item 245
# INFO:MyApp:Processing item 246
# WARNING:MyApp:Warning for item 246
# INFO:MyApp:Processing item 247
# WARNING:MyApp:Warning for item 247
# INFO:MyApp:Processing item 248
# WARNING:MyApp:Warning for item 248
# INFO:MyApp:Processing item 249
# WARNING:MyApp:Warning for item 249
# INFO:MyApp:Processing item 250
# WARNING:MyApp:Warning for item 250
# INFO:MyApp:Processing item 251
# WARNING:MyApp:Warning for item 251
# INFO:MyApp:Processing item 252
# WARNING:MyApp:Warning for item 252
# INFO:MyApp:Processing item 253
# WARNING:MyApp:Warning for item 253
# INFO:MyApp:Processing item 254
# WARNING:MyApp:Warning for item 254
# INFO:MyApp:Processing item 255
# WARNING:MyApp:Warning for item 255
# INFO:MyApp:Processing item 256
# WARNING:MyApp:Warning for item 256
# INFO:MyApp:Processing item 257
# WARNING:MyApp:Warning for item 257
# INFO:MyApp:Processing item 258
# WARNING:MyApp:Warning for item 258
# INFO:MyApp:Processing item 259
# WARNING:MyApp:Warning for item 259
# INFO:MyApp:Processing item 260
# WARNING:MyApp:Warning for item 260
# INFO:MyApp:Processing item 261
# WARNING:MyApp:Warning for item 261
# INFO:MyApp:Processing item 262
# WARNING:MyApp:Warning for item 262
# INFO:MyApp:Processing item 263
# WARNING:MyApp:Warning for item 263
# INFO:MyApp:Processing item 264
# WARNING:MyApp:Warning for item 264
# INFO:MyApp:Processing item 265
# WARNING:MyApp:Warning for item 265
# INFO:MyApp:Processing item 266
# WARNING:MyApp:Warning for item 266
# INFO:MyApp:Processing item 267
# WARNING:MyApp:Warning for item 267
# INFO:MyApp:Processing item 268
# WARNING:MyApp:Warning for item 268
# INFO:MyApp:Processing item 269
# WARNING:MyApp:Warning for item 269
# INFO:MyApp:Processing item 270
# WARNING:MyApp:Warning for item 270
# INFO:MyApp:Processing item 271
# WARNING:MyApp:Warning for item 271
# INFO:MyApp:Processing item 272
# WARNING:MyApp:Warning for item 272
# INFO:MyApp:Processing item 273
# WARNING:MyApp:Warning for item 273
# INFO:MyApp:Processing item 274
# WARNING:MyApp:Warning for item 274
# INFO:MyApp:Processing item 275
# WARNING:MyApp:Warning for item 275
# INFO:MyApp:Processing item 276
# WARNING:MyApp:Warning for item 276
# INFO:MyApp:Processing item 277
# WARNING:MyApp:Warning for item 277
# INFO:MyApp:Processing item 278
# WARNING:MyApp:Warning for item 278
# INFO:MyApp:Processing item 279
# WARNING:MyApp:Warning for item 279
# INFO:MyApp:Processing item 280
# WARNING:MyApp:Warning for item 280
# INFO:MyApp:Processing item 281
# WARNING:MyApp:Warning for item 281
# INFO:MyApp:Processing item 282
# WARNING:MyApp:Warning for item 282
# INFO:MyApp:Processing item 283
# WARNING:MyApp:Warning for item 283
# INFO:MyApp:Processing item 284
# WARNING:MyApp:Warning for item 284
# INFO:MyApp:Processing item 285
# WARNING:MyApp:Warning for item 285
# INFO:MyApp:Processing item 286
# WARNING:MyApp:Warning for item 286
# INFO:MyApp:Processing item 287
# WARNING:MyApp:Warning for item 287
# INFO:MyApp:Processing item 288
# WARNING:MyApp:Warning for item 288
# INFO:MyApp:Processing item 289
# WARNING:MyApp:Warning for item 289
# INFO:MyApp:Processing item 290
# WARNING:MyApp:Warning for item 290
# INFO:MyApp:Processing item 291
# WARNING:MyApp:Warning for item 291
# INFO:MyApp:Processing item 292
# WARNING:MyApp:Warning for item 292
# INFO:MyApp:Processing item 293
# WARNING:MyApp:Warning for item 293
# INFO:MyApp:Processing item 294
# WARNING:MyApp:Warning for item 294
# INFO:MyApp:Processing item 295
# WARNING:MyApp:Warning for item 295
# INFO:MyApp:Processing item 296
# WARNING:MyApp:Warning for item 296
# INFO:MyApp:Processing item 297
# WARNING:MyApp:Warning for item 297
# INFO:MyApp:Processing item 298
# WARNING:MyApp:Warning for item 298
# INFO:MyApp:Processing item 299
# WARNING:MyApp:Warning for item 299
# INFO:MyApp:Processing item 300
# WARNING:MyApp:Warning for item 300
# ERROR:MyApp:Error processing batch at item 300
# INFO:MyApp:Processing item 301
# WARNING:MyApp:Warning for item 301
# INFO:MyApp:Processing item 302
# WARNING:MyApp:Warning for item 302
# INFO:MyApp:Processing item 303
# WARNING:MyApp:Warning for item 303
# INFO:MyApp:Processing item 304
# WARNING:MyApp:Warning for item 304
# INFO:MyApp:Processing item 305
# WARNING:MyApp:Warning for item 305
# INFO:MyApp:Processing item 306
# WARNING:MyApp:Warning for item 306
# INFO:MyApp:Processing item 307
# WARNING:MyApp:Warning for item 307
# INFO:MyApp:Processing item 308
# WARNING:MyApp:Warning for item 308
# INFO:MyApp:Processing item 309
# WARNING:MyApp:Warning for item 309
# INFO:MyApp:Processing item 310
# WARNING:MyApp:Warning for item 310
# INFO:MyApp:Processing item 311
# WARNING:MyApp:Warning for item 311
# INFO:MyApp:Processing item 312
# WARNING:MyApp:Warning for item 312
# INFO:MyApp:Processing item 313
# WARNING:MyApp:Warning for item 313
# INFO:MyApp:Processing item 314
# WARNING:MyApp:Warning for item 314
# INFO:MyApp:Processing item 315
# WARNING:MyApp:Warning for item 315
# INFO:MyApp:Processing item 316
# WARNING:MyApp:Warning for item 316
# INFO:MyApp:Processing item 317
# WARNING:MyApp:Warning for item 317
# INFO:MyApp:Processing item 318
# WARNING:MyApp:Warning for item 318
# INFO:MyApp:Processing item 319
# WARNING:MyApp:Warning for item 319
# INFO:MyApp:Processing item 320
# WARNING:MyApp:Warning for item 320
# INFO:MyApp:Processing item 321
# WARNING:MyApp:Warning for item 321
# INFO:MyApp:Processing item 322
# WARNING:MyApp:Warning for item 322
# INFO:MyApp:Processing item 323
# WARNING:MyApp:Warning for item 323
# INFO:MyApp:Processing item 324
# WARNING:MyApp:Warning for item 324
# INFO:MyApp:Processing item 325
# WARNING:MyApp:Warning for item 325
# INFO:MyApp:Processing item 326
# WARNING:MyApp:Warning for item 326
# INFO:MyApp:Processing item 327
# WARNING:MyApp:Warning for item 327
# INFO:MyApp:Processing item 328
# WARNING:MyApp:Warning for item 328
# INFO:MyApp:Processing item 329
# WARNING:MyApp:Warning for item 329
# INFO:MyApp:Processing item 330
# WARNING:MyApp:Warning for item 330
# INFO:MyApp:Processing item 331
# WARNING:MyApp:Warning for item 331
# INFO:MyApp:Processing item 332
# WARNING:MyApp:Warning for item 332
# INFO:MyApp:Processing item 333
# WARNING:MyApp:Warning for item 333
# INFO:MyApp:Processing item 334
# WARNING:MyApp:Warning for item 334
# INFO:MyApp:Processing item 335
# WARNING:MyApp:Warning for item 335
# INFO:MyApp:Processing item 336
# WARNING:MyApp:Warning for item 336
# INFO:MyApp:Processing item 337
# WARNING:MyApp:Warning for item 337
# INFO:MyApp:Processing item 338
# WARNING:MyApp:Warning for item 338
# INFO:MyApp:Processing item 339
# WARNING:MyApp:Warning for item 339
# INFO:MyApp:Processing item 340
# WARNING:MyApp:Warning for item 340
# INFO:MyApp:Processing item 341
# WARNING:MyApp:Warning for item 341
# INFO:MyApp:Processing item 342
# WARNING:MyApp:Warning for item 342
# INFO:MyApp:Processing item 343
# WARNING:MyApp:Warning for item 343
# INFO:MyApp:Processing item 344
# WARNING:MyApp:Warning for item 344
# INFO:MyApp:Processing item 345
# WARNING:MyApp:Warning for item 345
# INFO:MyApp:Processing item 346
# WARNING:MyApp:Warning for item 346
# INFO:MyApp:Processing item 347
# WARNING:MyApp:Warning for item 347
# INFO:MyApp:Processing item 348
# WARNING:MyApp:Warning for item 348
# INFO:MyApp:Processing item 349
# WARNING:MyApp:Warning for item 349
# INFO:MyApp:Processing item 350
# WARNING:MyApp:Warning for item 350
# INFO:MyApp:Processing item 351
# WARNING:MyApp:Warning for item 351
# INFO:MyApp:Processing item 352
# WARNING:MyApp:Warning for item 352
# INFO:MyApp:Processing item 353
# WARNING:MyApp:Warning for item 353
# INFO:MyApp:Processing item 354
# WARNING:MyApp:Warning for item 354
# INFO:MyApp:Processing item 355
# WARNING:MyApp:Warning for item 355
# INFO:MyApp:Processing item 356
# WARNING:MyApp:Warning for item 356
# INFO:MyApp:Processing item 357
# WARNING:MyApp:Warning for item 357
# INFO:MyApp:Processing item 358
# WARNING:MyApp:Warning for item 358
# INFO:MyApp:Processing item 359
# WARNING:MyApp:Warning for item 359
# INFO:MyApp:Processing item 360
# WARNING:MyApp:Warning for item 360
# INFO:MyApp:Processing item 361
# WARNING:MyApp:Warning for item 361
# INFO:MyApp:Processing item 362
# WARNING:MyApp:Warning for item 362
# INFO:MyApp:Processing item 363
# WARNING:MyApp:Warning for item 363
# INFO:MyApp:Processing item 364
# WARNING:MyApp:Warning for item 364
# INFO:MyApp:Processing item 365
# WARNING:MyApp:Warning for item 365
# INFO:MyApp:Processing item 366
# WARNING:MyApp:Warning for item 366
# INFO:MyApp:Processing item 367
# WARNING:MyApp:Warning for item 367
# INFO:MyApp:Processing item 368
# WARNING:MyApp:Warning for item 368
# INFO:MyApp:Processing item 369
# WARNING:MyApp:Warning for item 369
# INFO:MyApp:Processing item 370
# WARNING:MyApp:Warning for item 370
# INFO:MyApp:Processing item 371
# WARNING:MyApp:Warning for item 371
# INFO:MyApp:Processing item 372
# WARNING:MyApp:Warning for item 372
# INFO:MyApp:Processing item 373
# WARNING:MyApp:Warning for item 373
# INFO:MyApp:Processing item 374
# WARNING:MyApp:Warning for item 374
# INFO:MyApp:Processing item 375
# WARNING:MyApp:Warning for item 375
# INFO:MyApp:Processing item 376
# WARNING:MyApp:Warning for item 376
# INFO:MyApp:Processing item 377
# WARNING:MyApp:Warning for item 377
# INFO:MyApp:Processing item 378
# WARNING:MyApp:Warning for item 378
# INFO:MyApp:Processing item 379
# WARNING:MyApp:Warning for item 379
# INFO:MyApp:Processing item 380
# WARNING:MyApp:Warning for item 380
# INFO:MyApp:Processing item 381
# WARNING:MyApp:Warning for item 381
# INFO:MyApp:Processing item 382
# WARNING:MyApp:Warning for item 382
# INFO:MyApp:Processing item 383
# WARNING:MyApp:Warning for item 383
# INFO:MyApp:Processing item 384
# WARNING:MyApp:Warning for item 384
# INFO:MyApp:Processing item 385
# WARNING:MyApp:Warning for item 385
# INFO:MyApp:Processing item 386
# WARNING:MyApp:Warning for item 386
# INFO:MyApp:Processing item 387
# WARNING:MyApp:Warning for item 387
# INFO:MyApp:Processing item 388
# WARNING:MyApp:Warning for item 388
# INFO:MyApp:Processing item 389
# WARNING:MyApp:Warning for item 389
# INFO:MyApp:Processing item 390
# WARNING:MyApp:Warning for item 390
# INFO:MyApp:Processing item 391
# WARNING:MyApp:Warning for item 391
# INFO:MyApp:Processing item 392
# WARNING:MyApp:Warning for item 392
# INFO:MyApp:Processing item 393
# WARNING:MyApp:Warning for item 393
# INFO:MyApp:Processing item 394
# WARNING:MyApp:Warning for item 394
# INFO:MyApp:Processing item 395
# WARNING:MyApp:Warning for item 395
# INFO:MyApp:Processing item 396
# WARNING:MyApp:Warning for item 396
# INFO:MyApp:Processing item 397
# WARNING:MyApp:Warning for item 397
# INFO:MyApp:Processing item 398
# WARNING:MyApp:Warning for item 398
# INFO:MyApp:Processing item 399
# WARNING:MyApp:Warning for item 399
# INFO:MyApp:Processing item 400
# WARNING:MyApp:Warning for item 400
# ERROR:MyApp:Error processing batch at item 400
# INFO:MyApp:Processing item 401
# WARNING:MyApp:Warning for item 401
# INFO:MyApp:Processing item 402
# WARNING:MyApp:Warning for item 402
# INFO:MyApp:Processing item 403
# WARNING:MyApp:Warning for item 403
# INFO:MyApp:Processing item 404
# WARNING:MyApp:Warning for item 404
# INFO:MyApp:Processing item 405
# WARNING:MyApp:Warning for item 405
# INFO:MyApp:Processing item 406
# WARNING:MyApp:Warning for item 406
# INFO:MyApp:Processing item 407
# WARNING:MyApp:Warning for item 407
# INFO:MyApp:Processing item 408
# WARNING:MyApp:Warning for item 408
# INFO:MyApp:Processing item 409
# WARNING:MyApp:Warning for item 409
# INFO:MyApp:Processing item 410
# WARNING:MyApp:Warning for item 410
# INFO:MyApp:Processing item 411
# WARNING:MyApp:Warning for item 411
# INFO:MyApp:Processing item 412
# WARNING:MyApp:Warning for item 412
# INFO:MyApp:Processing item 413
# WARNING:MyApp:Warning for item 413
# INFO:MyApp:Processing item 414
# WARNING:MyApp:Warning for item 414
# INFO:MyApp:Processing item 415
# WARNING:MyApp:Warning for item 415
# INFO:MyApp:Processing item 416
# WARNING:MyApp:Warning for item 416
# INFO:MyApp:Processing item 417
# WARNING:MyApp:Warning for item 417
# INFO:MyApp:Processing item 418
# WARNING:MyApp:Warning for item 418
# INFO:MyApp:Processing item 419
# WARNING:MyApp:Warning for item 419
# INFO:MyApp:Processing item 420
# WARNING:MyApp:Warning for item 420
# INFO:MyApp:Processing item 421
# WARNING:MyApp:Warning for item 421
# INFO:MyApp:Processing item 422
# WARNING:MyApp:Warning for item 422
# INFO:MyApp:Processing item 423
# WARNING:MyApp:Warning for item 423
# INFO:MyApp:Processing item 424
# WARNING:MyApp:Warning for item 424
# INFO:MyApp:Processing item 425
# WARNING:MyApp:Warning for item 425
# INFO:MyApp:Processing item 426
# WARNING:MyApp:Warning for item 426
# INFO:MyApp:Processing item 427
# WARNING:MyApp:Warning for item 427
# INFO:MyApp:Processing item 428
# WARNING:MyApp:Warning for item 428
# INFO:MyApp:Processing item 429
# WARNING:MyApp:Warning for item 429
# INFO:MyApp:Processing item 430
# WARNING:MyApp:Warning for item 430
# INFO:MyApp:Processing item 431
# WARNING:MyApp:Warning for item 431
# INFO:MyApp:Processing item 432
# WARNING:MyApp:Warning for item 432
# INFO:MyApp:Processing item 433
# WARNING:MyApp:Warning for item 433
# INFO:MyApp:Processing item 434
# WARNING:MyApp:Warning for item 434
# INFO:MyApp:Processing item 435
# WARNING:MyApp:Warning for item 435
# INFO:MyApp:Processing item 436
# WARNING:MyApp:Warning for item 436
# INFO:MyApp:Processing item 437
# WARNING:MyApp:Warning for item 437
# INFO:MyApp:Processing item 438
# WARNING:MyApp:Warning for item 438
# INFO:MyApp:Processing item 439
# WARNING:MyApp:Warning for item 439
# INFO:MyApp:Processing item 440
# WARNING:MyApp:Warning for item 440
# INFO:MyApp:Processing item 441
# WARNING:MyApp:Warning for item 441
# INFO:MyApp:Processing item 442
# WARNING:MyApp:Warning for item 442
# INFO:MyApp:Processing item 443
# WARNING:MyApp:Warning for item 443
# INFO:MyApp:Processing item 444
# WARNING:MyApp:Warning for item 444
# INFO:MyApp:Processing item 445
# WARNING:MyApp:Warning for item 445
# INFO:MyApp:Processing item 446
# WARNING:MyApp:Warning for item 446
# INFO:MyApp:Processing item 447
# WARNING:MyApp:Warning for item 447
# INFO:MyApp:Processing item 448
# WARNING:MyApp:Warning for item 448
# INFO:MyApp:Processing item 449
# WARNING:MyApp:Warning for item 449
# INFO:MyApp:Processing item 450
# WARNING:MyApp:Warning for item 450
# INFO:MyApp:Processing item 451
# WARNING:MyApp:Warning for item 451
# INFO:MyApp:Processing item 452
# WARNING:MyApp:Warning for item 452
# INFO:MyApp:Processing item 453
# WARNING:MyApp:Warning for item 453
# INFO:MyApp:Processing item 454
# WARNING:MyApp:Warning for item 454
# INFO:MyApp:Processing item 455
# WARNING:MyApp:Warning for item 455
# INFO:MyApp:Processing item 456
# WARNING:MyApp:Warning for item 456
# INFO:MyApp:Processing item 457
# WARNING:MyApp:Warning for item 457
# INFO:MyApp:Processing item 458
# WARNING:MyApp:Warning for item 458
# INFO:MyApp:Processing item 459
# WARNING:MyApp:Warning for item 459
# INFO:MyApp:Processing item 460
# WARNING:MyApp:Warning for item 460
# INFO:MyApp:Processing item 461
# WARNING:MyApp:Warning for item 461
# INFO:MyApp:Processing item 462
# WARNING:MyApp:Warning for item 462
# INFO:MyApp:Processing item 463
# WARNING:MyApp:Warning for item 463
# INFO:MyApp:Processing item 464
# WARNING:MyApp:Warning for item 464
# INFO:MyApp:Processing item 465
# WARNING:MyApp:Warning for item 465
# INFO:MyApp:Processing item 466
# WARNING:MyApp:Warning for item 466
# INFO:MyApp:Processing item 467
# WARNING:MyApp:Warning for item 467
# INFO:MyApp:Processing item 468
# WARNING:MyApp:Warning for item 468
# INFO:MyApp:Processing item 469
# WARNING:MyApp:Warning for item 469
# INFO:MyApp:Processing item 470
# WARNING:MyApp:Warning for item 470
# INFO:MyApp:Processing item 471
# WARNING:MyApp:Warning for item 471
# INFO:MyApp:Processing item 472
# WARNING:MyApp:Warning for item 472
# INFO:MyApp:Processing item 473
# WARNING:MyApp:Warning for item 473
# INFO:MyApp:Processing item 474
# WARNING:MyApp:Warning for item 474
# INFO:MyApp:Processing item 475
# WARNING:MyApp:Warning for item 475
# INFO:MyApp:Processing item 476
# WARNING:MyApp:Warning for item 476
# INFO:MyApp:Processing item 477
# WARNING:MyApp:Warning for item 477
# INFO:MyApp:Processing item 478
# WARNING:MyApp:Warning for item 478
# INFO:MyApp:Processing item 479
# WARNING:MyApp:Warning for item 479
# INFO:MyApp:Processing item 480
# WARNING:MyApp:Warning for item 480
# INFO:MyApp:Processing item 481
# WARNING:MyApp:Warning for item 481
# INFO:MyApp:Processing item 482
# WARNING:MyApp:Warning for item 482
# INFO:MyApp:Processing item 483
# WARNING:MyApp:Warning for item 483
# INFO:MyApp:Processing item 484
# WARNING:MyApp:Warning for item 484
# INFO:MyApp:Processing item 485
# WARNING:MyApp:Warning for item 485
# INFO:MyApp:Processing item 486
# WARNING:MyApp:Warning for item 486
# INFO:MyApp:Processing item 487
# WARNING:MyApp:Warning for item 487
# INFO:MyApp:Processing item 488
# WARNING:MyApp:Warning for item 488
# INFO:MyApp:Processing item 489
# WARNING:MyApp:Warning for item 489
# INFO:MyApp:Processing item 490
# WARNING:MyApp:Warning for item 490
# INFO:MyApp:Processing item 491
# WARNING:MyApp:Warning for item 491
# INFO:MyApp:Processing item 492
# WARNING:MyApp:Warning for item 492
# INFO:MyApp:Processing item 493
# WARNING:MyApp:Warning for item 493
# INFO:MyApp:Processing item 494
# WARNING:MyApp:Warning for item 494
# INFO:MyApp:Processing item 495
# WARNING:MyApp:Warning for item 495
# INFO:MyApp:Processing item 496
# WARNING:MyApp:Warning for item 496
# INFO:MyApp:Processing item 497
# WARNING:MyApp:Warning for item 497
# INFO:MyApp:Processing item 498
# WARNING:MyApp:Warning for item 498
# INFO:MyApp:Processing item 499
# WARNING:MyApp:Warning for item 499
# INFO:MyApp:Processing item 500
# WARNING:MyApp:Warning for item 500
# ERROR:MyApp:Error processing batch at item 500
# INFO:MyApp:Processing item 501
# WARNING:MyApp:Warning for item 501
# INFO:MyApp:Processing item 502
# WARNING:MyApp:Warning for item 502
# INFO:MyApp:Processing item 503
# WARNING:MyApp:Warning for item 503
# INFO:MyApp:Processing item 504
# WARNING:MyApp:Warning for item 504
# INFO:MyApp:Processing item 505
# WARNING:MyApp:Warning for item 505
# INFO:MyApp:Processing item 506
# WARNING:MyApp:Warning for item 506
# INFO:MyApp:Processing item 507
# WARNING:MyApp:Warning for item 507
# INFO:MyApp:Processing item 508
# WARNING:MyApp:Warning for item 508
# INFO:MyApp:Processing item 509
# WARNING:MyApp:Warning for item 509
# INFO:MyApp:Processing item 510
# WARNING:MyApp:Warning for item 510
# INFO:MyApp:Processing item 511
# WARNING:MyApp:Warning for item 511
# INFO:MyApp:Processing item 512
# WARNING:MyApp:Warning for item 512
# INFO:MyApp:Processing item 513
# WARNING:MyApp:Warning for item 513
# INFO:MyApp:Processing item 514
# WARNING:MyApp:Warning for item 514
# INFO:MyApp:Processing item 515
# WARNING:MyApp:Warning for item 515
# INFO:MyApp:Processing item 516
# WARNING:MyApp:Warning for item 516
# INFO:MyApp:Processing item 517
# WARNING:MyApp:Warning for item 517
# INFO:MyApp:Processing item 518
# WARNING:MyApp:Warning for item 518
# INFO:MyApp:Processing item 519
# WARNING:MyApp:Warning for item 519
# INFO:MyApp:Processing item 520
# WARNING:MyApp:Warning for item 520
# INFO:MyApp:Processing item 521
# WARNING:MyApp:Warning for item 521
# INFO:MyApp:Processing item 522
# WARNING:MyApp:Warning for item 522
# INFO:MyApp:Processing item 523
# WARNING:MyApp:Warning for item 523
# INFO:MyApp:Processing item 524
# WARNING:MyApp:Warning for item 524
# INFO:MyApp:Processing item 525
# WARNING:MyApp:Warning for item 525
# INFO:MyApp:Processing item 526
# WARNING:MyApp:Warning for item 526
# INFO:MyApp:Processing item 527
# WARNING:MyApp:Warning for item 527
# INFO:MyApp:Processing item 528
# WARNING:MyApp:Warning for item 528
# INFO:MyApp:Processing item 529
# WARNING:MyApp:Warning for item 529
# INFO:MyApp:Processing item 530
# WARNING:MyApp:Warning for item 530
# INFO:MyApp:Processing item 531
# WARNING:MyApp:Warning for item 531
# INFO:MyApp:Processing item 532
# WARNING:MyApp:Warning for item 532
# INFO:MyApp:Processing item 533
# WARNING:MyApp:Warning for item 533
# INFO:MyApp:Processing item 534
# WARNING:MyApp:Warning for item 534
# INFO:MyApp:Processing item 535
# WARNING:MyApp:Warning for item 535
# INFO:MyApp:Processing item 536
# WARNING:MyApp:Warning for item 536
# INFO:MyApp:Processing item 537
# WARNING:MyApp:Warning for item 537
# INFO:MyApp:Processing item 538
# WARNING:MyApp:Warning for item 538
# INFO:MyApp:Processing item 539
# WARNING:MyApp:Warning for item 539
# INFO:MyApp:Processing item 540
# WARNING:MyApp:Warning for item 540
# INFO:MyApp:Processing item 541
# WARNING:MyApp:Warning for item 541
# INFO:MyApp:Processing item 542
# WARNING:MyApp:Warning for item 542
# INFO:MyApp:Processing item 543
# WARNING:MyApp:Warning for item 543
# INFO:MyApp:Processing item 544
# WARNING:MyApp:Warning for item 544
# INFO:MyApp:Processing item 545
# WARNING:MyApp:Warning for item 545
# INFO:MyApp:Processing item 546
# WARNING:MyApp:Warning for item 546
# INFO:MyApp:Processing item 547
# WARNING:MyApp:Warning for item 547
# INFO:MyApp:Processing item 548
# WARNING:MyApp:Warning for item 548
# INFO:MyApp:Processing item 549
# WARNING:MyApp:Warning for item 549
# INFO:MyApp:Processing item 550
# WARNING:MyApp:Warning for item 550
# INFO:MyApp:Processing item 551
# WARNING:MyApp:Warning for item 551
# INFO:MyApp:Processing item 552
# WARNING:MyApp:Warning for item 552
# INFO:MyApp:Processing item 553
# WARNING:MyApp:Warning for item 553
# INFO:MyApp:Processing item 554
# WARNING:MyApp:Warning for item 554
# INFO:MyApp:Processing item 555
# WARNING:MyApp:Warning for item 555
# INFO:MyApp:Processing item 556
# WARNING:MyApp:Warning for item 556
# INFO:MyApp:Processing item 557
# WARNING:MyApp:Warning for item 557
# INFO:MyApp:Processing item 558
# WARNING:MyApp:Warning for item 558
# INFO:MyApp:Processing item 559
# WARNING:MyApp:Warning for item 559
# INFO:MyApp:Processing item 560
# WARNING:MyApp:Warning for item 560
# INFO:MyApp:Processing item 561
# WARNING:MyApp:Warning for item 561
# INFO:MyApp:Processing item 562
# WARNING:MyApp:Warning for item 562
# INFO:MyApp:Processing item 563
# WARNING:MyApp:Warning for item 563
# INFO:MyApp:Processing item 564
# WARNING:MyApp:Warning for item 564
# INFO:MyApp:Processing item 565
# WARNING:MyApp:Warning for item 565
# INFO:MyApp:Processing item 566
# WARNING:MyApp:Warning for item 566
# INFO:MyApp:Processing item 567
# WARNING:MyApp:Warning for item 567
# INFO:MyApp:Processing item 568
# WARNING:MyApp:Warning for item 568
# INFO:MyApp:Processing item 569
# WARNING:MyApp:Warning for item 569
# INFO:MyApp:Processing item 570
# WARNING:MyApp:Warning for item 570
# INFO:MyApp:Processing item 571
# WARNING:MyApp:Warning for item 571
# INFO:MyApp:Processing item 572
# WARNING:MyApp:Warning for item 572
# INFO:MyApp:Processing item 573
# WARNING:MyApp:Warning for item 573
# INFO:MyApp:Processing item 574
# WARNING:MyApp:Warning for item 574
# INFO:MyApp:Processing item 575
# WARNING:MyApp:Warning for item 575
# INFO:MyApp:Processing item 576
# WARNING:MyApp:Warning for item 576
# INFO:MyApp:Processing item 577
# WARNING:MyApp:Warning for item 577
# INFO:MyApp:Processing item 578
# WARNING:MyApp:Warning for item 578
# INFO:MyApp:Processing item 579
# WARNING:MyApp:Warning for item 579
# INFO:MyApp:Processing item 580
# WARNING:MyApp:Warning for item 580
# INFO:MyApp:Processing item 581
# WARNING:MyApp:Warning for item 581
# INFO:MyApp:Processing item 582
# WARNING:MyApp:Warning for item 582
# INFO:MyApp:Processing item 583
# WARNING:MyApp:Warning for item 583
# INFO:MyApp:Processing item 584
# WARNING:MyApp:Warning for item 584
# INFO:MyApp:Processing item 585
# WARNING:MyApp:Warning for item 585
# INFO:MyApp:Processing item 586
# WARNING:MyApp:Warning for item 586
# INFO:MyApp:Processing item 587
# WARNING:MyApp:Warning for item 587
# INFO:MyApp:Processing item 588
# WARNING:MyApp:Warning for item 588
# INFO:MyApp:Processing item 589
# WARNING:MyApp:Warning for item 589
# INFO:MyApp:Processing item 590
# WARNING:MyApp:Warning for item 590
# INFO:MyApp:Processing item 591
# WARNING:MyApp:Warning for item 591
# INFO:MyApp:Processing item 592
# WARNING:MyApp:Warning for item 592
# INFO:MyApp:Processing item 593
# WARNING:MyApp:Warning for item 593
# INFO:MyApp:Processing item 594
# WARNING:MyApp:Warning for item 594
# INFO:MyApp:Processing item 595
# WARNING:MyApp:Warning for item 595
# INFO:MyApp:Processing item 596
# WARNING:MyApp:Warning for item 596
# INFO:MyApp:Processing item 597
# WARNING:MyApp:Warning for item 597
# INFO:MyApp:Processing item 598
# WARNING:MyApp:Warning for item 598
# INFO:MyApp:Processing item 599
# WARNING:MyApp:Warning for item 599
# INFO:MyApp:Processing item 600
# WARNING:MyApp:Warning for item 600
# ERROR:MyApp:Error processing batch at item 600
# INFO:MyApp:Processing item 601
# WARNING:MyApp:Warning for item 601
# INFO:MyApp:Processing item 602
# WARNING:MyApp:Warning for item 602
# INFO:MyApp:Processing item 603
# WARNING:MyApp:Warning for item 603
# INFO:MyApp:Processing item 604
# WARNING:MyApp:Warning for item 604
# INFO:MyApp:Processing item 605
# WARNING:MyApp:Warning for item 605
# INFO:MyApp:Processing item 606
# WARNING:MyApp:Warning for item 606
# INFO:MyApp:Processing item 607
# WARNING:MyApp:Warning for item 607
# INFO:MyApp:Processing item 608
# WARNING:MyApp:Warning for item 608
# INFO:MyApp:Processing item 609
# WARNING:MyApp:Warning for item 609
# INFO:MyApp:Processing item 610
# WARNING:MyApp:Warning for item 610
# INFO:MyApp:Processing item 611
# WARNING:MyApp:Warning for item 611
# INFO:MyApp:Processing item 612
# WARNING:MyApp:Warning for item 612
# INFO:MyApp:Processing item 613
# WARNING:MyApp:Warning for item 613
# INFO:MyApp:Processing item 614
# WARNING:MyApp:Warning for item 614
# INFO:MyApp:Processing item 615
# WARNING:MyApp:Warning for item 615
# INFO:MyApp:Processing item 616
# WARNING:MyApp:Warning for item 616
# INFO:MyApp:Processing item 617
# WARNING:MyApp:Warning for item 617
# INFO:MyApp:Processing item 618
# WARNING:MyApp:Warning for item 618
# INFO:MyApp:Processing item 619
# WARNING:MyApp:Warning for item 619
# INFO:MyApp:Processing item 620
# WARNING:MyApp:Warning for item 620
# INFO:MyApp:Processing item 621
# WARNING:MyApp:Warning for item 621
# INFO:MyApp:Processing item 622
# WARNING:MyApp:Warning for item 622
# INFO:MyApp:Processing item 623
# WARNING:MyApp:Warning for item 623
# INFO:MyApp:Processing item 624
# WARNING:MyApp:Warning for item 624
# INFO:MyApp:Processing item 625
# WARNING:MyApp:Warning for item 625
# INFO:MyApp:Processing item 626
# WARNING:MyApp:Warning for item 626
# INFO:MyApp:Processing item 627
# WARNING:MyApp:Warning for item 627
# INFO:MyApp:Processing item 628
# WARNING:MyApp:Warning for item 628
# INFO:MyApp:Processing item 629
# WARNING:MyApp:Warning for item 629
# INFO:MyApp:Processing item 630
# WARNING:MyApp:Warning for item 630
# INFO:MyApp:Processing item 631
# WARNING:MyApp:Warning for item 631
# INFO:MyApp:Processing item 632
# WARNING:MyApp:Warning for item 632
# INFO:MyApp:Processing item 633
# WARNING:MyApp:Warning for item 633
# INFO:MyApp:Processing item 634
# WARNING:MyApp:Warning for item 634
# INFO:MyApp:Processing item 635
# WARNING:MyApp:Warning for item 635
# INFO:MyApp:Processing item 636
# WARNING:MyApp:Warning for item 636
# INFO:MyApp:Processing item 637
# WARNING:MyApp:Warning for item 637
# INFO:MyApp:Processing item 638
# WARNING:MyApp:Warning for item 638
# INFO:MyApp:Processing item 639
# WARNING:MyApp:Warning for item 639
# INFO:MyApp:Processing item 640
# WARNING:MyApp:Warning for item 640
# INFO:MyApp:Processing item 641
# WARNING:MyApp:Warning for item 641
# INFO:MyApp:Processing item 642
# WARNING:MyApp:Warning for item 642
# INFO:MyApp:Processing item 643
# WARNING:MyApp:Warning for item 643
# INFO:MyApp:Processing item 644
# WARNING:MyApp:Warning for item 644
# INFO:MyApp:Processing item 645
# WARNING:MyApp:Warning for item 645
# INFO:MyApp:Processing item 646
# WARNING:MyApp:Warning for item 646
# INFO:MyApp:Processing item 647
# WARNING:MyApp:Warning for item 647
# INFO:MyApp:Processing item 648
# WARNING:MyApp:Warning for item 648
# INFO:MyApp:Processing item 649
# WARNING:MyApp:Warning for item 649
# INFO:MyApp:Processing item 650
# WARNING:MyApp:Warning for item 650
# INFO:MyApp:Processing item 651
# WARNING:MyApp:Warning for item 651
# INFO:MyApp:Processing item 652
# WARNING:MyApp:Warning for item 652
# INFO:MyApp:Processing item 653
# WARNING:MyApp:Warning for item 653
# INFO:MyApp:Processing item 654
# WARNING:MyApp:Warning for item 654
# INFO:MyApp:Processing item 655
# WARNING:MyApp:Warning for item 655
# INFO:MyApp:Processing item 656
# WARNING:MyApp:Warning for item 656
# INFO:MyApp:Processing item 657
# WARNING:MyApp:Warning for item 657
# INFO:MyApp:Processing item 658
# WARNING:MyApp:Warning for item 658
# INFO:MyApp:Processing item 659
# WARNING:MyApp:Warning for item 659
# INFO:MyApp:Processing item 660
# WARNING:MyApp:Warning for item 660
# INFO:MyApp:Processing item 661
# WARNING:MyApp:Warning for item 661
# INFO:MyApp:Processing item 662
# WARNING:MyApp:Warning for item 662
# INFO:MyApp:Processing item 663
# WARNING:MyApp:Warning for item 663
# INFO:MyApp:Processing item 664
# WARNING:MyApp:Warning for item 664
# INFO:MyApp:Processing item 665
# WARNING:MyApp:Warning for item 665
# INFO:MyApp:Processing item 666
# WARNING:MyApp:Warning for item 666
# INFO:MyApp:Processing item 667
# WARNING:MyApp:Warning for item 667
# INFO:MyApp:Processing item 668
# WARNING:MyApp:Warning for item 668
# INFO:MyApp:Processing item 669
# WARNING:MyApp:Warning for item 669
# INFO:MyApp:Processing item 670
# WARNING:MyApp:Warning for item 670
# INFO:MyApp:Processing item 671
# WARNING:MyApp:Warning for item 671
# INFO:MyApp:Processing item 672
# WARNING:MyApp:Warning for item 672
# INFO:MyApp:Processing item 673
# WARNING:MyApp:Warning for item 673
# INFO:MyApp:Processing item 674
# WARNING:MyApp:Warning for item 674
# INFO:MyApp:Processing item 675
# WARNING:MyApp:Warning for item 675
# INFO:MyApp:Processing item 676
# WARNING:MyApp:Warning for item 676
# INFO:MyApp:Processing item 677
# WARNING:MyApp:Warning for item 677
# INFO:MyApp:Processing item 678
# WARNING:MyApp:Warning for item 678
# INFO:MyApp:Processing item 679
# WARNING:MyApp:Warning for item 679
# INFO:MyApp:Processing item 680
# WARNING:MyApp:Warning for item 680
# INFO:MyApp:Processing item 681
# WARNING:MyApp:Warning for item 681
# INFO:MyApp:Processing item 682
# WARNING:MyApp:Warning for item 682
# INFO:MyApp:Processing item 683
# WARNING:MyApp:Warning for item 683
# INFO:MyApp:Processing item 684
# WARNING:MyApp:Warning for item 684
# INFO:MyApp:Processing item 685
# WARNING:MyApp:Warning for item 685
# INFO:MyApp:Processing item 686
# WARNING:MyApp:Warning for item 686
# INFO:MyApp:Processing item 687
# WARNING:MyApp:Warning for item 687
# INFO:MyApp:Processing item 688
# WARNING:MyApp:Warning for item 688
# INFO:MyApp:Processing item 689
# WARNING:MyApp:Warning for item 689
# INFO:MyApp:Processing item 690
# WARNING:MyApp:Warning for item 690
# INFO:MyApp:Processing item 691
# WARNING:MyApp:Warning for item 691
# INFO:MyApp:Processing item 692
# WARNING:MyApp:Warning for item 692
# INFO:MyApp:Processing item 693
# WARNING:MyApp:Warning for item 693
# INFO:MyApp:Processing item 694
# WARNING:MyApp:Warning for item 694
# INFO:MyApp:Processing item 695
# WARNING:MyApp:Warning for item 695
# INFO:MyApp:Processing item 696
# WARNING:MyApp:Warning for item 696
# INFO:MyApp:Processing item 697
# WARNING:MyApp:Warning for item 697
# INFO:MyApp:Processing item 698
# WARNING:MyApp:Warning for item 698
# INFO:MyApp:Processing item 699
# WARNING:MyApp:Warning for item 699
# INFO:MyApp:Processing item 700
# WARNING:MyApp:Warning for item 700
# ERROR:MyApp:Error processing batch at item 700
# INFO:MyApp:Processing item 701
# WARNING:MyApp:Warning for item 701
# INFO:MyApp:Processing item 702
# WARNING:MyApp:Warning for item 702
# INFO:MyApp:Processing item 703
# WARNING:MyApp:Warning for item 703
# INFO:MyApp:Processing item 704
# WARNING:MyApp:Warning for item 704
# INFO:MyApp:Processing item 705
# WARNING:MyApp:Warning for item 705
# INFO:MyApp:Processing item 706
# WARNING:MyApp:Warning for item 706
# INFO:MyApp:Processing item 707
# WARNING:MyApp:Warning for item 707
# INFO:MyApp:Processing item 708
# WARNING:MyApp:Warning for item 708
# INFO:MyApp:Processing item 709
# WARNING:MyApp:Warning for item 709
# INFO:MyApp:Processing item 710
# WARNING:MyApp:Warning for item 710
# INFO:MyApp:Processing item 711
# WARNING:MyApp:Warning for item 711
# INFO:MyApp:Processing item 712
# WARNING:MyApp:Warning for item 712
# INFO:MyApp:Processing item 713
# WARNING:MyApp:Warning for item 713
# INFO:MyApp:Processing item 714
# WARNING:MyApp:Warning for item 714
# INFO:MyApp:Processing item 715
# WARNING:MyApp:Warning for item 715
# INFO:MyApp:Processing item 716
# WARNING:MyApp:Warning for item 716
# INFO:MyApp:Processing item 717
# WARNING:MyApp:Warning for item 717
# INFO:MyApp:Processing item 718
# WARNING:MyApp:Warning for item 718
# INFO:MyApp:Processing item 719
# WARNING:MyApp:Warning for item 719
# INFO:MyApp:Processing item 720
# WARNING:MyApp:Warning for item 720
# INFO:MyApp:Processing item 721
# WARNING:MyApp:Warning for item 721
# INFO:MyApp:Processing item 722
# WARNING:MyApp:Warning for item 722
# INFO:MyApp:Processing item 723
# WARNING:MyApp:Warning for item 723
# INFO:MyApp:Processing item 724
# ...
# INFO:MyApp:Processing item 759
# WARNING:MyApp:Warning for item 759
# INFO:MyApp:Processing item 760
# WARNING:MyApp:Warning for item 760
# INFO:MyApp:Processing item 761
# WARNING:MyApp:Warning for item 761
# INFO:MyApp:Processing item 762
# WARNING:MyApp:Warning for item 762
# INFO:MyApp:Processing item 763
# WARNING:MyApp:Warning for item 763
# INFO:MyApp:Processing item 764
# WARNING:MyApp:Warning for item 764
# INFO:MyApp:Processing item 765
# WARNING:MyApp:Warning for item 765
# INFO:MyApp:Processing item 766
# WARNING:MyApp:Warning for item 766
# INFO:MyApp:Processing item 767
# WARNING:MyApp:Warning for item 767
# INFO:MyApp:Processing item 768
# WARNING:MyApp:Warning for item 768
# INFO:MyApp:Processing item 769
# WARNING:MyApp:Warning for item 769
# INFO:MyApp:Processing item 770
# WARNING:MyApp:Warning for item 770
# INFO:MyApp:Processing item 771
# WARNING:MyApp:Warning for item 771
# INFO:MyApp:Processing item 772
# WARNING:MyApp:Warning for item 772
# INFO:MyApp:Processing item 773
# WARNING:MyApp:Warning for item 773
# INFO:MyApp:Processing item 774
# WARNING:MyApp:Warning for item 774
# INFO:MyApp:Processing item 775
# WARNING:MyApp:Warning for item 775
# INFO:MyApp:Processing item 776
# WARNING:MyApp:Warning for item 776
# INFO:MyApp:Processing item 777
# WARNING:MyApp:Warning for item 777
# INFO:MyApp:Processing item 778
# WARNING:MyApp:Warning for item 778
# INFO:MyApp:Processing item 779
# WARNING:MyApp:Warning for item 779
# INFO:MyApp:Processing item 780
# WARNING:MyApp:Warning for item 780
# INFO:MyApp:Processing item 781
# WARNING:MyApp:Warning for item 781
# INFO:MyApp:Processing item 782
# WARNING:MyApp:Warning for item 782
# INFO:MyApp:Processing item 783
# WARNING:MyApp:Warning for item 783
# INFO:MyApp:Processing item 784
# WARNING:MyApp:Warning for item 784
# INFO:MyApp:Processing item 785
# WARNING:MyApp:Warning for item 785
# INFO:MyApp:Processing item 786
# WARNING:MyApp:Warning for item 786
# INFO:MyApp:Processing item 787
# WARNING:MyApp:Warning for item 787
# INFO:MyApp:Processing item 788
# WARNING:MyApp:Warning for item 788
# INFO:MyApp:Processing item 789
# WARNING:MyApp:Warning for item 789
# INFO:MyApp:Processing item 790
# WARNING:MyApp:Warning for item 790
# INFO:MyApp:Processing item 791
# WARNING:MyApp:Warning for item 791
# INFO:MyApp:Processing item 792
# WARNING:MyApp:Warning for item 792
# INFO:MyApp:Processing item 793
# WARNING:MyApp:Warning for item 793
# INFO:MyApp:Processing item 794
# WARNING:MyApp:Warning for item 794
# INFO:MyApp:Processing item 795
# WARNING:MyApp:Warning for item 795
# INFO:MyApp:Processing item 796
# WARNING:MyApp:Warning for item 796
# INFO:MyApp:Processing item 797
# WARNING:MyApp:Warning for item 797
# INFO:MyApp:Processing item 798
# WARNING:MyApp:Warning for item 798
# INFO:MyApp:Processing item 799
# WARNING:MyApp:Warning for item 799
# INFO:MyApp:Processing item 800
# WARNING:MyApp:Warning for item 800
# ERROR:MyApp:Error processing batch at item 800
# INFO:MyApp:Processing item 801
# WARNING:MyApp:Warning for item 801
# INFO:MyApp:Processing item 802
# WARNING:MyApp:Warning for item 802
# INFO:MyApp:Processing item 803
# WARNING:MyApp:Warning for item 803
# INFO:MyApp:Processing item 804
# WARNING:MyApp:Warning for item 804
# INFO:MyApp:Processing item 805
# WARNING:MyApp:Warning for item 805
# INFO:MyApp:Processing item 806
# WARNING:MyApp:Warning for item 806
# INFO:MyApp:Processing item 807
# WARNING:MyApp:Warning for item 807
# INFO:MyApp:Processing item 808
# WARNING:MyApp:Warning for item 808
# INFO:MyApp:Processing item 809
# WARNING:MyApp:Warning for item 809
# INFO:MyApp:Processing item 810
# WARNING:MyApp:Warning for item 810
# INFO:MyApp:Processing item 811
# WARNING:MyApp:Warning for item 811
# INFO:MyApp:Processing item 812
# WARNING:MyApp:Warning for item 812
# INFO:MyApp:Processing item 813
# WARNING:MyApp:Warning for item 813
# INFO:MyApp:Processing item 814
# WARNING:MyApp:Warning for item 814
# INFO:MyApp:Processing item 815
# WARNING:MyApp:Warning for item 815
# INFO:MyApp:Processing item 816
# WARNING:MyApp:Warning for item 816
# INFO:MyApp:Processing item 817
# WARNING:MyApp:Warning for item 817
# INFO:MyApp:Processing item 818
# WARNING:MyApp:Warning for item 818
# INFO:MyApp:Processing item 819
# WARNING:MyApp:Warning for item 819
# INFO:MyApp:Processing item 820
# WARNING:MyApp:Warning for item 820
# INFO:MyApp:Processing item 821
# WARNING:MyApp:Warning for item 821
# INFO:MyApp:Processing item 822
# WARNING:MyApp:Warning for item 822
# INFO:MyApp:Processing item 823
# WARNING:MyApp:Warning for item 823
# INFO:MyApp:Processing item 824
# WARNING:MyApp:Warning for item 824
# INFO:MyApp:Processing item 825
# WARNING:MyApp:Warning for item 825
# INFO:MyApp:Processing item 826
# WARNING:MyApp:Warning for item 826
# INFO:MyApp:Processing item 827
# WARNING:MyApp:Warning for item 827
# INFO:MyApp:Processing item 828
# WARNING:MyApp:Warning for item 828
# INFO:MyApp:Processing item 829
# WARNING:MyApp:Warning for item 829
# INFO:MyApp:Processing item 830
# WARNING:MyApp:Warning for item 830
# INFO:MyApp:Processing item 831
# WARNING:MyApp:Warning for item 831
# INFO:MyApp:Processing item 832
# WARNING:MyApp:Warning for item 832
# INFO:MyApp:Processing item 833
# WARNING:MyApp:Warning for item 833
# INFO:MyApp:Processing item 834
# WARNING:MyApp:Warning for item 834
# INFO:MyApp:Processing item 835
# WARNING:MyApp:Warning for item 835
# INFO:MyApp:Processing item 836
# WARNING:MyApp:Warning for item 836
# INFO:MyApp:Processing item 837
# WARNING:MyApp:Warning for item 837
# INFO:MyApp:Processing item 838
# WARNING:MyApp:Warning for item 838
# INFO:MyApp:Processing item 839
# WARNING:MyApp:Warning for item 839
# INFO:MyApp:Processing item 840
# WARNING:MyApp:Warning for item 840
# INFO:MyApp:Processing item 841
# WARNING:MyApp:Warning for item 841
# INFO:MyApp:Processing item 842
# WARNING:MyApp:Warning for item 842
# INFO:MyApp:Processing item 843
# WARNING:MyApp:Warning for item 843
# INFO:MyApp:Processing item 844
# WARNING:MyApp:Warning for item 844
# INFO:MyApp:Processing item 845
# WARNING:MyApp:Warning for item 845
# INFO:MyApp:Processing item 846
# WARNING:MyApp:Warning for item 846
# INFO:MyApp:Processing item 847
# WARNING:MyApp:Warning for item 847
# INFO:MyApp:Processing item 848
# WARNING:MyApp:Warning for item 848
# INFO:MyApp:Processing item 849
# WARNING:MyApp:Warning for item 849
# INFO:MyApp:Processing item 850
# WARNING:MyApp:Warning for item 850
# INFO:MyApp:Processing item 851
# WARNING:MyApp:Warning for item 851
# INFO:MyApp:Processing item 852
# WARNING:MyApp:Warning for item 852
# INFO:MyApp:Processing item 853
# WARNING:MyApp:Warning for item 853
# INFO:MyApp:Processing item 854
# WARNING:MyApp:Warning for item 854
# INFO:MyApp:Processing item 855
# WARNING:MyApp:Warning for item 855
# INFO:MyApp:Processing item 856
# WARNING:MyApp:Warning for item 856
# INFO:MyApp:Processing item 857
# WARNING:MyApp:Warning for item 857
# INFO:MyApp:Processing item 858
# WARNING:MyApp:Warning for item 858
# INFO:MyApp:Processing item 859
# WARNING:MyApp:Warning for item 859
# INFO:MyApp:Processing item 860
# WARNING:MyApp:Warning for item 860
# INFO:MyApp:Processing item 861
# WARNING:MyApp:Warning for item 861
# INFO:MyApp:Processing item 862
# WARNING:MyApp:Warning for item 862
# INFO:MyApp:Processing item 863
# WARNING:MyApp:Warning for item 863
# INFO:MyApp:Processing item 864
# WARNING:MyApp:Warning for item 864
# INFO:MyApp:Processing item 865
# WARNING:MyApp:Warning for item 865
# INFO:MyApp:Processing item 866
# WARNING:MyApp:Warning for item 866
# INFO:MyApp:Processing item 867
# WARNING:MyApp:Warning for item 867
# INFO:MyApp:Processing item 868
# WARNING:MyApp:Warning for item 868
# INFO:MyApp:Processing item 869
# WARNING:MyApp:Warning for item 869
# INFO:MyApp:Processing item 870
# WARNING:MyApp:Warning for item 870
# INFO:MyApp:Processing item 871
# WARNING:MyApp:Warning for item 871
# INFO:MyApp:Processing item 872
# WARNING:MyApp:Warning for item 872
# INFO:MyApp:Processing item 873
# WARNING:MyApp:Warning for item 873
# INFO:MyApp:Processing item 874
# WARNING:MyApp:Warning for item 874
# INFO:MyApp:Processing item 875
# WARNING:MyApp:Warning for item 875
# INFO:MyApp:Processing item 876
# WARNING:MyApp:Warning for item 876
# INFO:MyApp:Processing item 877
# WARNING:MyApp:Warning for item 877
# INFO:MyApp:Processing item 878
# WARNING:MyApp:Warning for item 878
# INFO:MyApp:Processing item 879
# WARNING:MyApp:Warning for item 879
# INFO:MyApp:Processing item 880
# WARNING:MyApp:Warning for item 880
# INFO:MyApp:Processing item 881
# WARNING:MyApp:Warning for item 881
# INFO:MyApp:Processing item 882
# WARNING:MyApp:Warning for item 882
# INFO:MyApp:Processing item 883
# WARNING:MyApp:Warning for item 883
# INFO:MyApp:Processing item 884
# WARNING:MyApp:Warning for item 884
# INFO:MyApp:Processing item 885
# WARNING:MyApp:Warning for item 885
# INFO:MyApp:Processing item 886
# WARNING:MyApp:Warning for item 886
# INFO:MyApp:Processing item 887
# WARNING:MyApp:Warning for item 887
# INFO:MyApp:Processing item 888
# WARNING:MyApp:Warning for item 888
# INFO:MyApp:Processing item 889
# WARNING:MyApp:Warning for item 889
# INFO:MyApp:Processing item 890
# WARNING:MyApp:Warning for item 890
# INFO:MyApp:Processing item 891
# WARNING:MyApp:Warning for item 891
# INFO:MyApp:Processing item 892
# WARNING:MyApp:Warning for item 892
# INFO:MyApp:Processing item 893
# WARNING:MyApp:Warning for item 893
# INFO:MyApp:Processing item 894
# WARNING:MyApp:Warning for item 894
# INFO:MyApp:Processing item 895
# WARNING:MyApp:Warning for item 895
# INFO:MyApp:Processing item 896
# WARNING:MyApp:Warning for item 896
# INFO:MyApp:Processing item 897
# WARNING:MyApp:Warning for item 897
# INFO:MyApp:Processing item 898
# WARNING:MyApp:Warning for item 898
# INFO:MyApp:Processing item 899
# WARNING:MyApp:Warning for item 899
# INFO:MyApp:Processing item 900
# WARNING:MyApp:Warning for item 900
# ERROR:MyApp:Error processing batch at item 900
# INFO:MyApp:Processing item 901
# WARNING:MyApp:Warning for item 901
# INFO:MyApp:Processing item 902
# WARNING:MyApp:Warning for item 902
# INFO:MyApp:Processing item 903
# WARNING:MyApp:Warning for item 903
# INFO:MyApp:Processing item 904
# WARNING:MyApp:Warning for item 904
# INFO:MyApp:Processing item 905
# WARNING:MyApp:Warning for item 905
# INFO:MyApp:Processing item 906
# WARNING:MyApp:Warning for item 906
# INFO:MyApp:Processing item 907
# WARNING:MyApp:Warning for item 907
# INFO:MyApp:Processing item 908
# WARNING:MyApp:Warning for item 908
# INFO:MyApp:Processing item 909
# WARNING:MyApp:Warning for item 909
# INFO:MyApp:Processing item 910
# WARNING:MyApp:Warning for item 910
# INFO:MyApp:Processing item 911
# WARNING:MyApp:Warning for item 911
# INFO:MyApp:Processing item 912
# WARNING:MyApp:Warning for item 912
# INFO:MyApp:Processing item 913
# WARNING:MyApp:Warning for item 913
# INFO:MyApp:Processing item 914
# WARNING:MyApp:Warning for item 914
# INFO:MyApp:Processing item 915
# WARNING:MyApp:Warning for item 915
# INFO:MyApp:Processing item 916
# WARNING:MyApp:Warning for item 916
# INFO:MyApp:Processing item 917
# WARNING:MyApp:Warning for item 917
# INFO:MyApp:Processing item 918
# WARNING:MyApp:Warning for item 918
# INFO:MyApp:Processing item 919
# WARNING:MyApp:Warning for item 919
# INFO:MyApp:Processing item 920
# WARNING:MyApp:Warning for item 920
# INFO:MyApp:Processing item 921
# WARNING:MyApp:Warning for item 921
# INFO:MyApp:Processing item 922
# WARNING:MyApp:Warning for item 922
# INFO:MyApp:Processing item 923
# WARNING:MyApp:Warning for item 923
# INFO:MyApp:Processing item 924
# WARNING:MyApp:Warning for item 924
# INFO:MyApp:Processing item 925
# WARNING:MyApp:Warning for item 925
# INFO:MyApp:Processing item 926
# WARNING:MyApp:Warning for item 926
# INFO:MyApp:Processing item 927
# WARNING:MyApp:Warning for item 927
# INFO:MyApp:Processing item 928
# WARNING:MyApp:Warning for item 928
# INFO:MyApp:Processing item 929
# WARNING:MyApp:Warning for item 929
# INFO:MyApp:Processing item 930
# WARNING:MyApp:Warning for item 930
# INFO:MyApp:Processing item 931
# WARNING:MyApp:Warning for item 931
# INFO:MyApp:Processing item 932
# WARNING:MyApp:Warning for item 932
# INFO:MyApp:Processing item 933
# WARNING:MyApp:Warning for item 933
# INFO:MyApp:Processing item 934
# WARNING:MyApp:Warning for item 934
# INFO:MyApp:Processing item 935
# WARNING:MyApp:Warning for item 935
# INFO:MyApp:Processing item 936
# WARNING:MyApp:Warning for item 936
# INFO:MyApp:Processing item 937
# WARNING:MyApp:Warning for item 937
# INFO:MyApp:Processing item 938
# WARNING:MyApp:Warning for item 938
# INFO:MyApp:Processing item 939
# WARNING:MyApp:Warning for item 939
# INFO:MyApp:Processing item 940
# WARNING:MyApp:Warning for item 940
# INFO:MyApp:Processing item 941
# WARNING:MyApp:Warning for item 941
# INFO:MyApp:Processing item 942
# WARNING:MyApp:Warning for item 942
# INFO:MyApp:Processing item 943
# WARNING:MyApp:Warning for item 943
# INFO:MyApp:Processing item 944
# WARNING:MyApp:Warning for item 944
# INFO:MyApp:Processing item 945
# WARNING:MyApp:Warning for item 945
# INFO:MyApp:Processing item 946
# WARNING:MyApp:Warning for item 946
# INFO:MyApp:Processing item 947
# WARNING:MyApp:Warning for item 947
# INFO:MyApp:Processing item 948
# WARNING:MyApp:Warning for item 948
# INFO:MyApp:Processing item 949
# WARNING:MyApp:Warning for item 949
# INFO:MyApp:Processing item 950
# WARNING:MyApp:Warning for item 950
# INFO:MyApp:Processing item 951
# WARNING:MyApp:Warning for item 951
# INFO:MyApp:Processing item 952
# WARNING:MyApp:Warning for item 952
# INFO:MyApp:Processing item 953
# WARNING:MyApp:Warning for item 953
# INFO:MyApp:Processing item 954
# WARNING:MyApp:Warning for item 954
# INFO:MyApp:Processing item 955
# WARNING:MyApp:Warning for item 955
# INFO:MyApp:Processing item 956
# WARNING:MyApp:Warning for item 956
# INFO:MyApp:Processing item 957
# WARNING:MyApp:Warning for item 957
# INFO:MyApp:Processing item 958
# WARNING:MyApp:Warning for item 958
# INFO:MyApp:Processing item 959
# WARNING:MyApp:Warning for item 959
# INFO:MyApp:Processing item 960
# WARNING:MyApp:Warning for item 960
# INFO:MyApp:Processing item 961
# WARNING:MyApp:Warning for item 961
# INFO:MyApp:Processing item 962
# WARNING:MyApp:Warning for item 962
# INFO:MyApp:Processing item 963
# WARNING:MyApp:Warning for item 963
# INFO:MyApp:Processing item 964
# WARNING:MyApp:Warning for item 964
# INFO:MyApp:Processing item 965
# WARNING:MyApp:Warning for item 965
# INFO:MyApp:Processing item 966
# WARNING:MyApp:Warning for item 966
# INFO:MyApp:Processing item 967
# WARNING:MyApp:Warning for item 967
# INFO:MyApp:Processing item 968
# WARNING:MyApp:Warning for item 968
# INFO:MyApp:Processing item 969
# WARNING:MyApp:Warning for item 969
# INFO:MyApp:Processing item 970
# WARNING:MyApp:Warning for item 970
# INFO:MyApp:Processing item 971
# WARNING:MyApp:Warning for item 971
# INFO:MyApp:Processing item 972
# WARNING:MyApp:Warning for item 972
# INFO:MyApp:Processing item 973
# WARNING:MyApp:Warning for item 973
# INFO:MyApp:Processing item 974
# WARNING:MyApp:Warning for item 974
# INFO:MyApp:Processing item 975
# WARNING:MyApp:Warning for item 975
# INFO:MyApp:Processing item 976
# WARNING:MyApp:Warning for item 976
# INFO:MyApp:Processing item 977
# WARNING:MyApp:Warning for item 977
# INFO:MyApp:Processing item 978
# WARNING:MyApp:Warning for item 978
# INFO:MyApp:Processing item 979
# WARNING:MyApp:Warning for item 979
# INFO:MyApp:Processing item 980
# WARNING:MyApp:Warning for item 980
# INFO:MyApp:Processing item 981
# WARNING:MyApp:Warning for item 981
# INFO:MyApp:Processing item 982
# WARNING:MyApp:Warning for item 982
# INFO:MyApp:Processing item 983
# WARNING:MyApp:Warning for item 983
# INFO:MyApp:Processing item 984
# WARNING:MyApp:Warning for item 984
# INFO:MyApp:Processing item 985
# WARNING:MyApp:Warning for item 985
# INFO:MyApp:Processing item 986
# WARNING:MyApp:Warning for item 986
# INFO:MyApp:Processing item 987
# WARNING:MyApp:Warning for item 987
# INFO:MyApp:Processing item 988
# WARNING:MyApp:Warning for item 988
# INFO:MyApp:Processing item 989
# WARNING:MyApp:Warning for item 989
# INFO:MyApp:Processing item 990
# WARNING:MyApp:Warning for item 990
# INFO:MyApp:Processing item 991
# WARNING:MyApp:Warning for item 991
# INFO:MyApp:Processing item 992
# WARNING:MyApp:Warning for item 992
# INFO:MyApp:Processing item 993
# WARNING:MyApp:Warning for item 993
# INFO:MyApp:Processing item 994
# WARNING:MyApp:Warning for item 994
# INFO:MyApp:Processing item 995
# WARNING:MyApp:Warning for item 995
# INFO:MyApp:Processing item 996
# WARNING:MyApp:Warning for item 996
# INFO:MyApp:Processing item 997
# WARNING:MyApp:Warning for item 997
# INFO:MyApp:Processing item 998
# WARNING:MyApp:Warning for item 998
# INFO:MyApp:Processing item 999
# WARNING:MyApp:Warning for item 999

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block.
# - > Answer:-

# %%
def handle_index_and_key_errors(data, identifier):
    try:
        if isinstance(data, (list, tuple)):
            # Try to access by index
            result = data[identifier]
        elif isinstance(data, dict):
            # Try to access by key
            result = data[identifier]
        else:
            raise TypeError("Data must be list, tuple, or dictionary")

        print(f"Found value: {result}")
        return result

    except (IndexError, KeyError) as e:
        print(f"Access error: {type(e).__name__} - {e}")
        return None
    except TypeError as e:
        print(f"Type error: {e}")
        return None

# Usage
my_list = [10, 20, 30]
my_dict = {'x': 100, 'y': 200}

handle_index_and_key_errors(my_list, 1)    # Works: 20
handle_index_and_key_errors(my_list, 10)   # IndexError
handle_index_and_key_errors(my_dict, 'x')  # Works: 100
handle_index_and_key_errors(my_dict, 'z')  # KeyError
# Out:
# Found value: 20
# Access error: IndexError - list index out of range
# Found value: 100
# Access error: KeyError - 'z'

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python?
# - > Answer:-

# %%
def read_with_context_manager(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        print(f"File '{filename}' not found.")
        return None
    except IOError as e:
        print(f"Error reading file: {e}")
        return None

# Reading line by line with context manager
def read_lines_with_context(filename):
    try:
        with open(filename, 'r') as file:
            for line in file:
                yield line.rstrip()
    except FileNotFoundError:
        print(f"File '{filename}' not found.")

# Usage
for line in read_lines_with_context('data.txt'):
    print(line)
# Out:
# File 'data.txt' not found.

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.
# - > Answer:-

# %%
def count_word_occurrences(filename, target_word):
    try:
        with open(filename, 'r') as file:
            content = file.read().lower()
            target_word = target_word.lower()

            # Count whole word occurrences
            import re
            pattern = r'\b' + re.escape(target_word) + r'\b'
            matches = re.findall(pattern, content)
            count = len(matches)

            print(f"The word '{target_word}' appears {count} times in '{filename}'")
            return count

    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return 0
    except IOError as e:
        print(f"Error reading file: {e}")
        return 0

# Alternative simpler method (case-sensitive)
def count_word_simple(filename, target_word):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            words = content.split()
            count = words.count(target_word)
            print(f"'{target_word}' appears {count} times")
            return count
    except FileNotFoundError:
        print(f"File '{filename}' not found.")
        return 0

# Usage
count_word_occurrences('text.txt', 'python')
# Out:
# Error: File 'text.txt' not found.
# 0

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents?
# - > Answer:-

# %%
import os

def is_file_empty(filename):
    try:
        return os.path.getsize(filename) == 0
    except OSError:
        return False

def read_non_empty_file(filename):
    if not os.path.exists(filename):
        print(f"File '{filename}' does not exist.")
        return None

    if is_file_empty(filename):
        print(f"File '{filename}' is empty.")
        return ""

    try:
        with open(filename, 'r') as file:
            return file.read()
    except IOError as e:
        print(f"Error reading file: {e}")
        return None

# Usage
content = read_non_empty_file('data.txt')
# Out:
# File 'data.txt' does not exist.

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling.
# - > Answer:-

# %%
import logging
import os
from datetime import datetime

# Configure logging for file handling errors
def setup_file_handling_logger():
    # Create logs directory
    if not os.path.exists('logs'):
        os.makedirs('logs')

    # Setup logger
    logger = logging.getLogger('FileHandler')
    logger.setLevel(logging.DEBUG)

    # Create file handler for errors
    error_handler = logging.FileHandler('logs/file_handling_errors.log')
    error_handler.setLevel(logging.ERROR)

    # Create file handler for all activities
    activity_handler = logging.FileHandler('logs/file_activities.log')
    activity_handler.setLevel(logging.INFO)

    # Create console handler
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.WARNING)

    # Create formatter
    formatter = logging.Formatter(
        '%(asctime)s - %(name)s - %(levelname)s - %(funcName)s:%(lineno)d - %(message)s'
    )

    # Set formatter for all handlers
    error_handler.setFormatter(formatter)
    activity_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)

    # Add handlers to logger
    logger.addHandler(error_handler)
    logger.addHandler(activity_handler)
    logger.addHandler(console_handler)

    return logger

class FileManager:
    def __init__(self):
        self.logger = setup_file_handling_logger()

    def read_file(self, filename):
        """Read file with comprehensive error logging"""
        self.logger.info(f"Attempting to read file: {filename}")

        try:
            with open(filename, 'r') as file:
                content = file.read()

            self.logger.info(f"Successfully read {len(content)} characters from {filename}")
            return content

        except FileNotFoundError:
            error_msg = f"File not found: {filename}"
            self.logger.error(error_msg)
            return None

        except PermissionError:
            error_msg = f"Permission denied when reading: {filename}"
            self.logger.error(error_msg)
            return None

        except UnicodeDecodeError as e:
            error_msg = f"Unicode decode error in {filename}: {e}"
            self.logger.error(error_msg)
            return None

        except IOError as e:
            error_msg = f"IO error reading {filename}: {e}"
            self.logger.error(error_msg)
            return None

        except Exception as e:
            error_msg = f"Unexpected error reading {filename}: {e}"
            self.logger.error(error_msg)
            return None

    def write_file(self, filename, content):
        """Write file with comprehensive error logging"""
        self.logger.info(f"Attempting to write to file: {filename}")

        try:
            with open(filename, 'w') as file:
                file.write(content)

            self.logger.info(f"Successfully wrote {len(content)} characters to {filename}")
            return True

        except PermissionError:
            error_msg = f"Permission denied when writing to: {filename}"
            self.logger.error(error_msg)
            return False

        except IOError as e:
            error_msg = f"IO error writing to {filename}: {e}"
            self.logger.error(error_msg)
            return False

        except Exception as e:
            error_msg = f"Unexpected error writing to {filename}: {e}"
            self.logger.error(error_msg)
            return False

    def copy_file(self, source, destination):
        """Copy file with error logging"""
        self.logger.info(f"Attempting to copy {source} to {destination}")

        try:
            content = self.read_file(source)
            if content is not None:
                success = self.write_file(destination, content)
                if success:
                    self.logger.info(f"Successfully copied {source} to {destination}")
                    return True

            self.logger.error(f"Failed to copy {source} to {destination}")
            return False

        except Exception as e:
            error_msg = f"Unexpected error during copy operation: {e}"
            self.logger.error(error_msg)
            return False

    def process_multiple_files(self, file_list):
        """Process multiple files and log all activities"""
        self.logger.info(f"Starting batch processing of {len(file_list)} files")

        results = []
        for filename in file_list:
            try:
                content = self.read_file(filename)
                if content is not None:
                    # Simulate processing
                    processed_content = content.upper()
                    output_filename = f"processed_{filename}"

                    if self.write_file(output_filename, processed_content):
                        results.append((filename, True, "Success"))
                    else:
                        results.append((filename, False, "Write failed"))
                else:
                    results.append((filename, False, "Read failed"))

            except Exception as e:
                error_msg = f"Error processing {filename}: {e}"
                self.logger.error(error_msg)
                results.append((filename, False, str(e)))

        # Log summary
        successful = sum(1 for _, success, _ in results if success)
        self.logger.info(f"Batch processing completed: {successful}/{len(file_list)} files processed successfully")

        return results

# Usage and demonstration
def demonstrate_file_handling_with_logging():
    fm = FileManager()

    # Create test files
    test_files = {
        'test1.txt': 'Hello World',
        'test2.txt': 'Python Programming',
        'test3.txt': 'File Handling Example'
    }

    print("Creating test files...")
    for filename, content in test_files.items():
        fm.write_file(filename, content)

    print("\nReading files...")
    for filename in test_files.keys():
        content = fm.read_file(filename)
        if content:
            print(f"{filename}: {content[:20]}...")

    print("\nTesting error scenarios...")
    # Try to read non-existent file
    fm.read_file('nonexistent.txt')

    # Try to write to invalid path
    fm.write_file('/invalid/path/file.txt', 'test')

    # Process multiple files
    print("\nBatch processing...")
    file_list = ['test1.txt', 'test2.txt', 'nonexistent.txt', 'test3.txt']
    results = fm.process_multiple_files(file_list)

    for filename, success, message in results:
        status = "✓" if success else "✗"
        print(f"{status} {filename}: {message}")

# Run demonstration
if __name__ == "__main__":
    demonstrate_file_handling_with_logging()
# Out:
# INFO:FileHandler:Attempting to write to file: test1.txt
# INFO:FileHandler:Successfully wrote 11 characters to test1.txt
# INFO:FileHandler:Attempting to write to file: test2.txt
# INFO:FileHandler:Successfully wrote 18 characters to test2.txt
# INFO:FileHandler:Attempting to write to file: test3.txt
# INFO:FileHandler:Successfully wrote 21 characters to test3.txt
# INFO:FileHandler:Attempting to read file: test1.txt
# INFO:FileHandler:Successfully read 11 characters from test1.txt
# INFO:FileHandler:Attempting to read file: test2.txt
# INFO:FileHandler:Successfully read 18 characters from test2.txt
# INFO:FileHandler:Attempting to read file: test3.txt
# INFO:FileHandler:Successfully read 21 characters from test3.txt
# INFO:FileHandler:Attempting to read file: nonexistent.txt
# 2025-09-02 14:05:32,272 - FileHandler - ERROR - read_file:61 - File not found: nonexistent.txt
# ERROR:FileHandler:File not found: nonexistent.txt
# INFO:FileHandler:Attempting to write to file: /invalid/path/file.txt
# 2025-09-02 14:05:32,280 - FileHandler - ERROR - write_file:102 - IO error writing to /invalid/path/file.txt: [Errno 2] No such file or directory: '/invalid/path/file.txt'
# ERROR:FileHandler:IO error writing to /invalid/path/file.txt: [Errno 2] No such file or directory: '/invalid/path/file.txt'
# INFO:FileHandler:Starting batch processing of 4 files
# INFO:FileHandler:Attempting to read file: test1.txt
# INFO:FileHandler:Successfully read 11 characters from test1.txt
# INFO:FileHandler:Attempting to write to file: processed_test1.txt
# INFO:FileHandler:Successfully wrote 11 characters to processed_test1.txt
# INFO:FileHandler:Attempting to read file: test2.txt
# INFO:FileHandler:Successfully read 18 characters from test2.txt
# INFO:FileHandler:Attempting to write to file: processed_test2.txt
# INFO:FileHandler:Successfully wrote 18 characters to processed_test2.txt
# INFO:FileHandler:Attempting to read file: nonexistent.txt
# 2025-09-02 14:05:32,300 - FileHandler - ERROR - read_file:61 - File not found: nonexistent.txt
# ERROR:FileHandler:File not found: nonexistent.txt
# INFO:FileHandler:Attempting to read file: test3.txt
# INFO:FileHandler:Successfully read 21 characters from test3.txt
# INFO:FileHandler:Attempting to write to file: processed_test3.txt
# INFO:FileHandler:Successfully wrote 21 characters to processed_test3.txt
# INFO:FileHandler:Batch processing completed: 3/4 files processed successfully
# Creating test files...
#
# Reading files...
# test1.txt: Hello World...
# test2.txt: Python Programming...
# test3.txt: File Handling Exampl...
#
# Testing error scenarios...
#
# Batch processing...
# ✓ test1.txt: Success
# ✓ test2.txt: Success
# ✗ nonexistent.txt: Read failed
# ✓ test3.txt: Success
